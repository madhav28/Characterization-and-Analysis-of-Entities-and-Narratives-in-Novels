# %% [markdown]
# ### Import Statements

# %%
import pandas as pd
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')

# %% [markdown]
# ### Load Data

# %%
data = pd.read_csv("agatha_christie_narrative_with_explaination.csv")
data[["Author","Book","Document","Narrative_GPT","Explanation"]]
# Out:
#              Author                             Book  \
# 0   Agatha Christie             The Secret Adversary
# 1   Agatha Christie             The Secret Adversary
# 2   Agatha Christie             The Secret Adversary
# 3   Agatha Christie             The Secret Adversary
# 4   Agatha Christie             The Secret Adversary
# 5   Agatha Christie             The Secret Adversary
# 6   Agatha Christie             The Secret Adversary
# 7   Agatha Christie             The Secret Adversary
# 8   Agatha Christie             The Secret Adversary
# 9   Agatha Christie             The Secret Adversary
# 10  Agatha Christie             The Secret Adversary
# 11  Agatha Christie             The Secret Adversary
# 12  Agatha Christie             The Secret Adversary
# 13  Agatha Christie             The Secret Adversary
# 14  Agatha Christie             The Secret Adversary
# 15  Agatha Christie             The Secret Adversary
# 16  Agatha Christie             The Secret Adversary
# 17  Agatha Christie             The Secret Adversary
# 18  Agatha Christie             The Secret Adversary
# 19  Agatha Christie             The Secret Adversary
# 20  Agatha Christie             The Secret Adversary
# 21  Agatha Christie             The Secret Adversary
# 22  Agatha Christie             The Secret Adversary
# 23  Agatha Christie             The Secret Adversary
# 24  Agatha Christie             The Secret Adversary
# 25  Agatha Christie  The Mysterious Affair at Styles
# 26  Agatha Christie  The Mysterious Affair at Styles
# 27  Agatha Christie  The Mysterious Affair at Styles
# 28  Agatha Christie  The Mysterious Affair at Styles
# 29  Agatha Christie  The Mysterious Affair at Styles
# 30  Agatha Christie  The Mysterious Affair at Styles
# 31  Agatha Christie  The Mysterious Affair at Styles
# 32  Agatha Christie  The Mysterious Affair at Styles
# 33  Agatha Christie  The Mysterious Affair at Styles
# 34  Agatha Christie  The Mysterious Affair at Styles
# 35  Agatha Christie  The Mysterious Affair at Styles
# 36  Agatha Christie  The Mysterious Affair at Styles
# 37  Agatha Christie  The Mysterious Affair at Styles
# 38  Agatha Christie  The Mysterious Affair at Styles
# 39  Agatha Christie  The Mysterious Affair at Styles
# 40  Agatha Christie  The Mysterious Affair at Styles
# 41  Agatha Christie  The Mysterious Affair at Styles
# 42  Agatha Christie  The Mysterious Affair at Styles
# 43  Agatha Christie  The Mysterious Affair at Styles
# 44  Agatha Christie  The Mysterious Affair at Styles
# 45  Agatha Christie  The Mysterious Affair at Styles
# 46  Agatha Christie  The Mysterious Affair at Styles
# 47  Agatha Christie  The Mysterious Affair at Styles
# 48  Agatha Christie  The Mysterious Affair at Styles
# 49  Agatha Christie  The Mysterious Affair at Styles
#
#                                              Document  \
# 0   THE SECRET ADVERSARY By Agatha Christie TO ALL...
# 1   man's voice beside her made her start and turn...
# 2   take them?" The girl held out her hand. "Wait-...
# 3   We're getting a bit unpopular here--blocking t...
# 4   a table, catching odds and ends of conversatio...
# 5   came at last, and Tuppence, rousing herself fr...
# 6   Lieutenant Thomas Beresford. Eleventh and twel...
# 7   job hunting! There aren't any jobs! And, if th...
# 8   early Victorian view that short skirts and smo...
# 9   sharply. "Certainly not," agreed Tommy hastily...
# 10  If we could make ourselves known, people might...
# 11  have hairpins and powder-puffs." Tommy handed ...
# 12  a lunatic." "It's not half so insane as a thin...
# 13  moment?" CHAPTER II. MR. WHITTINGTON'S OFFER T...
# 14  my proposition before you." "At eleven o'clock...
# 15  catch him," she murmured. "Anyway, it's worth ...
# 16  and walked into a small rather dirty outer off...
# 17  To herself she said: "Of course, if father hea...
# 18  for granted." Whittington looked surprised. "S...
# 19  geniality had faded out of Whittington's face....
# 20  likely, isn't it, then there would be two girl...
# 21  you, Mr. Whittington." "So we come to the usua...
# 22  counted the notes in a businesslike manner, se...
# 23  induced the driver to move away. "Well," said ...
# 24  "They're not Fishers. They're five times bette...
# 25  THE MYSTERIOUS AFFAIR AT STYLES By Agatha Chri...
# 26  place in Essex. We had a good yarn about old t...
# 27  profession of medicine, and lived at home whil...
# 28  in all weathers! But the mater cottoned to him...
# 29  running its appointed course. I felt I had sud...
# 30  with a hearty, almost painful, grip. I had an ...
# 31  woman's that I have ever known; the intense po...
# 32  lady, with a somewhat masterful cast of featur...
# 33  forthcoming bazaar which she was organizing an...
# 34  wonderfully clever." "Like a good detective st...
# 35  and I admired the great loose waves of her aub...
# 36  Member's wife--she was the late Lord Abbotsbur...
# 37  next morning dawned bright and sunny, and I wa...
# 38  Farmer Raikes has got a very pretty young wife...
# 39  her." "Of course, Miss Howard," I said, "I'll ...
# 40  "Come for a stroll, Hastings. This has been a ...
# 41  say. That is, up to now. Since her marriage, o...
# 42  long expeditions with him. I must confess that...
# 43  in her briskest mood about 12.30, and swept La...
# 44  laugh. "If you people only knew how fatally ea...
# 45  table outside the door. I laughed. "Discipline...
# 46  cried. "It is indeed mon ami Hastings!" "Poiro...
# 47  house inhabited by him and his fellow Belgians...
# 48  quick game of tennis before supper and, Cynthi...
# 49  hope she's found him out at last!" "Was Dorcas...
#
#                                         Narrative_GPT  \
# 0   Adventure and crisis (narrative) - Individual ...
# 1   Suspenseful encounter with a mysterious man (n...
# 2   Danger and secrecy (narrative) - Tasked with a...
# 3   Social dynamics and economic challenges (narra...
# 4   Eavesdropping and Overhearing (narrative) - Ca...
# 5   Catching up and reminiscing (narrative) - Prog...
# 6   Career Endeavors and War Experiences (narrativ...
# 7   Desperation in job searching (narrative) - Lac...
# 8   Social norms and expectations versus personal ...
# 9   Seeking fortune through unconventional methods...
# 10                                                NaN
# 11  Crafting an identity and appeal for adventures...
# 12                                                NaN
# 13  Unexpected encounter and suspicious offer (nar...
# 14  Engagement in espionage and adventure (narrati...
# 15  Anticipation of new opportunities (narrative) ...
# 16  Entering a suspicious environment (narrative) ...
# 17  Concealing true identity and intentions (narra...
# 18  Evaluating business propositions and partnersh...
# 19  Deception and confrontation (narrative) - Pret...
# 20  Negotiation and Power Play (narrative) - Lever...
# 21  Negotiation and subterfuge (narrative) - Strat...
# 22  Surprise and Revelry (narrative) - A playful y...
# 23  Confusion and disbelief in communication (narr...
# 24  Adventurous undertakings in the urban expanse ...
# 25  Narrative Setting (narrative) - An old acquain...
# 26  Revisiting familial connections and estates (n...
# 27  Family dynamics and financial dependency (narr...
# 28  Unexpected and controversial marriage (narrati...
# 29  Disruption from an outsider (narrative) - A se...
# 30  Greeting and interaction among characters (nar...
# 31  Elegant social gathering and communication (na...
# 32  Introduction of new characters at Styles (narr...
# 33  Social gathering planning (narrative) - Dislik...
# 34  Engaging in mystery and speculative deduction ...
# 35  Social interactions and dynamics at a gatherin...
# 36  Frugality and resourcefulness in wartime (narr...
# 37  Revealing personal conflicts and consequences ...
# 38  Tension and distrust in social relations (narr...
# 39  Caution and vigilance advised (narrative) - Su...
# 40  Tension and inheritance struggles (narrative) ...
# 41  Change and Uncertainty (narrative) - Shift in ...
# 42  Preparations and excitement for a local event ...
# 43  Social gathering and casual visit (narrative) ...
# 44                                                NaN
# 45  Social interactions and observations (narrativ...
# 46  Reunion and Reminiscence (narrative) - Old acq...
# 47  Social dynamics and tensions within the househ...
# 48  Tension and conflict within family relationshi...
# 49  Family tensions and secrets (narrative) - Susp...
#
#                                           Explanation
# 0   The passage from "The Secret Adversary" by Aga...
# 1   The passage showcases a suspenseful encounter ...
# 2   The passage presents a scenario where a charac...
# 3   The passage portrays Tommy and Tuppence engagi...
# 4   The narrative of "Eavesdropping and Overhearin...
# 5   The passage illustrates a scenario where two c...
# 6   The passage details a series of diverse job ro...
# 7   The narrative of "Desperation in job searching...
# 8   The narrative of "Social norms and expectation...
# 9   The passage delves into a conversation between...
# 10  The passage from "The Secret Adversary" involv...
# 11  The passage clearly portrays Tommy and Tuppenc...
# 12  The narrative of "Questioning the measurements...
# 13  The passage portrays a sudden encounter betwee...
# 14  The narrative of "Engagement in espionage and ...
# 15  The narrative of "Anticipation of new opportun...
# 16  The narrative stems from the setting and the i...
# 17  The narrative "Concealing true identity and in...
# 18  The passage depicts a situation where Tuppence...
# 19  The passage reflects a narrative of deception ...
# 20  The passage clearly depicts a situation where ...
# 21  The narrative of "Negotiation and subterfuge" ...
# 22  The narrative "Surprise and Revelry" is apt fo...
# 23  The passage describes a sequence where Mr. Ber...
# 24  The narrative and subnarrative identified as “...
# 25  The passage introduces the setting by discussi...
# 26  The passage revolves around a reunion and a vi...
# 27  The narrative is drawn from the passage which ...
# 28  The narrative was chosen based on the context ...
# 29  The narrative "Disruption from an outsider" fi...
# 30  The passage describes a scenario where charact...
# 31  The passage presents an elegant social setting...
# 32  The passage introduces new characters, Mr. Has...
# 33  The narrative of "Social gathering planning" i...
# 34  The passage revolves around a conversation con...
# 35  The passage predominantly revolves around a so...
# 36  The narrative of "Frugality and resourcefulnes...
# 37  The narrative of "Revealing personal conflicts...
# 38  The narrative "Tension and distrust in social ...
# 39  The narrative of "Caution and vigilance advise...
# 40  The narrative of "tension and inheritance stru...
# 41  The passage described a sense of distress brou...
# 42  The passage revolves around preparations for a...
# 43  The passage encompasses a social gathering hig...
# 44  The narrative provided is incorrect as no spec...
# 45  The chosen narrative, "Social interactions and...
# 46  The narrative of "Reunion and Reminiscence" fi...
# 47  The passage reveals underlying tensions and a ...
# 48  The narrative "Tension and conflict within fam...
# 49  The chosen narrative of "Family tensions and s...

# %% [markdown]
# ### Vector-Based Retrieval

# %% [markdown]
# #### Embed Documents

# %%
documents = data['Document'].tolist()
embeddings = model.encode(documents, convert_to_tensor=False)  # Generates embeddings as NumPy arrays
embeddings
# Out:
# array([[-0.13713561, -0.02760365, -0.00776269, ...,  0.05107752,
#         -0.06473309,  0.0442661 ],
#        [-0.03862067, -0.00285315, -0.00076801, ..., -0.00302249,
#         -0.08816168, -0.04733606],
#        [-0.04679669,  0.03039258,  0.03098541, ...,  0.05883805,
#         -0.11628671, -0.00176512],
#        ...,
#        [-0.00273278,  0.06691949,  0.014451  , ...,  0.06435476,
#         -0.00358517, -0.01496139],
#        [-0.01918934,  0.03531448,  0.05827264, ...,  0.02213561,
#         -0.04942799,  0.00559354],
#        [-0.02389337,  0.02386251,  0.06686441, ...,  0.00309378,
#         -0.02799714, -0.00683206]], dtype=float32)

# %%
embeddings_array = np.array(embeddings)
dimension = embeddings_array.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings_array)

# %%
data['index'] = range(len(data))
metadata = data[['index', 'Book','Author', 'Narrative_GPT','Explanation']]
metadata.iloc[:49]
# Out:
#     index                             Book           Author  \
# 0       0             The Secret Adversary  Agatha Christie
# 1       1             The Secret Adversary  Agatha Christie
# 2       2             The Secret Adversary  Agatha Christie
# 3       3             The Secret Adversary  Agatha Christie
# 4       4             The Secret Adversary  Agatha Christie
# 5       5             The Secret Adversary  Agatha Christie
# 6       6             The Secret Adversary  Agatha Christie
# 7       7             The Secret Adversary  Agatha Christie
# 8       8             The Secret Adversary  Agatha Christie
# 9       9             The Secret Adversary  Agatha Christie
# 10     10             The Secret Adversary  Agatha Christie
# 11     11             The Secret Adversary  Agatha Christie
# 12     12             The Secret Adversary  Agatha Christie
# 13     13             The Secret Adversary  Agatha Christie
# 14     14             The Secret Adversary  Agatha Christie
# 15     15             The Secret Adversary  Agatha Christie
# 16     16             The Secret Adversary  Agatha Christie
# 17     17             The Secret Adversary  Agatha Christie
# 18     18             The Secret Adversary  Agatha Christie
# 19     19             The Secret Adversary  Agatha Christie
# 20     20             The Secret Adversary  Agatha Christie
# 21     21             The Secret Adversary  Agatha Christie
# 22     22             The Secret Adversary  Agatha Christie
# 23     23             The Secret Adversary  Agatha Christie
# 24     24             The Secret Adversary  Agatha Christie
# 25     25  The Mysterious Affair at Styles  Agatha Christie
# 26     26  The Mysterious Affair at Styles  Agatha Christie
# 27     27  The Mysterious Affair at Styles  Agatha Christie
# 28     28  The Mysterious Affair at Styles  Agatha Christie
# 29     29  The Mysterious Affair at Styles  Agatha Christie
# 30     30  The Mysterious Affair at Styles  Agatha Christie
# 31     31  The Mysterious Affair at Styles  Agatha Christie
# 32     32  The Mysterious Affair at Styles  Agatha Christie
# 33     33  The Mysterious Affair at Styles  Agatha Christie
# 34     34  The Mysterious Affair at Styles  Agatha Christie
# 35     35  The Mysterious Affair at Styles  Agatha Christie
# 36     36  The Mysterious Affair at Styles  Agatha Christie
# 37     37  The Mysterious Affair at Styles  Agatha Christie
# 38     38  The Mysterious Affair at Styles  Agatha Christie
# 39     39  The Mysterious Affair at Styles  Agatha Christie
# 40     40  The Mysterious Affair at Styles  Agatha Christie
# 41     41  The Mysterious Affair at Styles  Agatha Christie
# 42     42  The Mysterious Affair at Styles  Agatha Christie
# 43     43  The Mysterious Affair at Styles  Agatha Christie
# 44     44  The Mysterious Affair at Styles  Agatha Christie
# 45     45  The Mysterious Affair at Styles  Agatha Christie
# 46     46  The Mysterious Affair at Styles  Agatha Christie
# 47     47  The Mysterious Affair at Styles  Agatha Christie
# 48     48  The Mysterious Affair at Styles  Agatha Christie
# 49     49  The Mysterious Affair at Styles  Agatha Christie
#
#                                         Narrative_GPT  \
# 0   Adventure and crisis (narrative) - Individual ...
# 1   Suspenseful encounter with a mysterious man (n...
# 2   Danger and secrecy (narrative) - Tasked with a...
# 3   Social dynamics and economic challenges (narra...
# 4   Eavesdropping and Overhearing (narrative) - Ca...
# 5   Catching up and reminiscing (narrative) - Prog...
# 6   Career Endeavors and War Experiences (narrativ...
# 7   Desperation in job searching (narrative) - Lac...
# 8   Social norms and expectations versus personal ...
# 9   Seeking fortune through unconventional methods...
# 10                                                NaN
# 11  Crafting an identity and appeal for adventures...
# 12                                                NaN
# 13  Unexpected encounter and suspicious offer (nar...
# 14  Engagement in espionage and adventure (narrati...
# 15  Anticipation of new opportunities (narrative) ...
# 16  Entering a suspicious environment (narrative) ...
# 17  Concealing true identity and intentions (narra...
# 18  Evaluating business propositions and partnersh...
# 19  Deception and confrontation (narrative) - Pret...
# 20  Negotiation and Power Play (narrative) - Lever...
# 21  Negotiation and subterfuge (narrative) - Strat...
# 22  Surprise and Revelry (narrative) - A playful y...
# 23  Confusion and disbelief in communication (narr...
# 24  Adventurous undertakings in the urban expanse ...
# 25  Narrative Setting (narrative) - An old acquain...
# 26  Revisiting familial connections and estates (n...
# 27  Family dynamics and financial dependency (narr...
# 28  Unexpected and controversial marriage (narrati...
# 29  Disruption from an outsider (narrative) - A se...
# 30  Greeting and interaction among characters (nar...
# 31  Elegant social gathering and communication (na...
# 32  Introduction of new characters at Styles (narr...
# 33  Social gathering planning (narrative) - Dislik...
# 34  Engaging in mystery and speculative deduction ...
# 35  Social interactions and dynamics at a gatherin...
# 36  Frugality and resourcefulness in wartime (narr...
# 37  Revealing personal conflicts and consequences ...
# 38  Tension and distrust in social relations (narr...
# 39  Caution and vigilance advised (narrative) - Su...
# 40  Tension and inheritance struggles (narrative) ...
# 41  Change and Uncertainty (narrative) - Shift in ...
# 42  Preparations and excitement for a local event ...
# 43  Social gathering and casual visit (narrative) ...
# 44                                                NaN
# 45  Social interactions and observations (narrativ...
# 46  Reunion and Reminiscence (narrative) - Old acq...
# 47  Social dynamics and tensions within the househ...
# 48  Tension and conflict within family relationshi...
# 49  Family tensions and secrets (narrative) - Susp...
#
#                                           Explanation
# 0   The passage from "The Secret Adversary" by Aga...
# 1   The passage showcases a suspenseful encounter ...
# 2   The passage presents a scenario where a charac...
# 3   The passage portrays Tommy and Tuppence engagi...
# 4   The narrative of "Eavesdropping and Overhearin...
# 5   The passage illustrates a scenario where two c...
# 6   The passage details a series of diverse job ro...
# 7   The narrative of "Desperation in job searching...
# 8   The narrative of "Social norms and expectation...
# 9   The passage delves into a conversation between...
# 10  The passage from "The Secret Adversary" involv...
# 11  The passage clearly portrays Tommy and Tuppenc...
# 12  The narrative of "Questioning the measurements...
# 13  The passage portrays a sudden encounter betwee...
# 14  The narrative of "Engagement in espionage and ...
# 15  The narrative of "Anticipation of new opportun...
# 16  The narrative stems from the setting and the i...
# 17  The narrative "Concealing true identity and in...
# 18  The passage depicts a situation where Tuppence...
# 19  The passage reflects a narrative of deception ...
# 20  The passage clearly depicts a situation where ...
# 21  The narrative of "Negotiation and subterfuge" ...
# 22  The narrative "Surprise and Revelry" is apt fo...
# 23  The passage describes a sequence where Mr. Ber...
# 24  The narrative and subnarrative identified as “...
# 25  The passage introduces the setting by discussi...
# 26  The passage revolves around a reunion and a vi...
# 27  The narrative is drawn from the passage which ...
# 28  The narrative was chosen based on the context ...
# 29  The narrative "Disruption from an outsider" fi...
# 30  The passage describes a scenario where charact...
# 31  The passage presents an elegant social setting...
# 32  The passage introduces new characters, Mr. Has...
# 33  The narrative of "Social gathering planning" i...
# 34  The passage revolves around a conversation con...
# 35  The passage predominantly revolves around a so...
# 36  The narrative of "Frugality and resourcefulnes...
# 37  The narrative of "Revealing personal conflicts...
# 38  The narrative "Tension and distrust in social ...
# 39  The narrative of "Caution and vigilance advise...
# 40  The narrative of "tension and inheritance stru...
# 41  The passage described a sense of distress brou...
# 42  The passage revolves around preparations for a...
# 43  The passage encompasses a social gathering hig...
# 44  The narrative provided is incorrect as no spec...
# 45  The chosen narrative, "Social interactions and...
# 46  The narrative of "Reunion and Reminiscence" fi...
# 47  The passage reveals underlying tensions and a ...
# 48  The narrative "Tension and conflict within fam...
# 49  The chosen narrative of "Family tensions and s...

# %% [markdown]
# #### Create Index

# %%
def embed_query(query_text):
    query_embedding = model.encode([query_text])[0]
    return np.array([query_embedding])

# %%
def retrieve_documents(query, top_k=5):
    query_embedding = embed_query(query)
    distances, indices = index.search(query_embedding, top_k)
    
    results = metadata[metadata['index'].isin(indices[0])]
    results['distance'] = distances[0]
    
    return results[['Book','Author', 'Narrative_GPT','distance']]

# %%
query_text = "old acquaintance meeting in a countryside estats"
results = retrieve_documents(query_text, top_k=3)

results
# Out:
# /var/folders/rw/0tvxrjxd6xgg15ts3dc0z8p80000gn/T/ipykernel_49362/3686153020.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results['distance'] = distances[0]
#                                Book           Author  \
# 31  The Mysterious Affair at Styles  Agatha Christie
# 33  The Mysterious Affair at Styles  Agatha Christie
# 42  The Mysterious Affair at Styles  Agatha Christie
#
#                                         Narrative_GPT  distance
# 31  Elegant social gathering and communication (na...  1.292583
# 33  Social gathering planning (narrative) - Dislik...  1.296220
# 42  Preparations and excitement for a local event ...  1.306005

# %% [markdown]
# ### Knowledge Graph Construction

# %%
from neo4j import GraphDatabase

# %%
class KnowledgeGraph:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))
    
    def close(self):
        self.driver.close()

    def create_graph(self, data):
        with self.driver.session() as session:
            # Convert DataFrame rows into dictionaries
            data_dict = data.to_dict(orient='records')
            for row in data_dict:
                session.execute_write(self._create_nodes_and_relationships, row)
    
    @staticmethod
    def _create_nodes_and_relationships(tx, row):
        # Create the query to add nodes and relationships
        query = """
        MERGE (author:Author {name: $author})
        MERGE (book:Book {title: $book})
        MERGE (narrative:Narrative {text: $narrative})
        MERGE (explanation:Explanation {text: $explanation})
        MERGE (author)-[:WROTE]->(book)
        MERGE (book)-[:HAS]->(narrative)
        MERGE (narrative)-[:HAS]->(explanation)
        """
        # Run the query
        tx.run(query, author=row["Author"], book=row["Book"],narrative=row["Narrative_GPT"], explanation=row["Explanation"])
    
    def query_graph_for_narrative(self, narrative_text):
        with self.driver.session() as session:
            query = """
            MATCH (n:Narrative)-[:HAS]->(e:Explanation)
            WHERE n.text CONTAINS $narrative_text
            RETURN n.text AS narrative, e.text AS explanation
            """
            # Run the query and fetch all results into a list
            result = session.run(query, narrative_text=narrative_text)
            records = [record.data() for record in result]  # Consume result immediately
            return records

# %%
data_graph=data.copy().dropna()

# %%
uri = ""
user = ""
password = ""

graph = KnowledgeGraph(uri, user, password)
graph.create_graph(data_graph)
graph.close()

# %%
narrative_test = "Adventure and crisis"
graph = KnowledgeGraph(uri, user, password)
graph_results = graph.query_graph_for_narrative(narrative_test)
graph.close()
print(graph_results)
# Out:
# [{'narrative': 'Adventure and crisis (narrative) - Individual courage and stoic resolve in dire situations (subnarrative)', 'explanation': 'The passage from "The Secret Adversary" by Agatha Christie sets a scene of immediate danger and adventure as it describes the sinking of the Lusitania, a situation filled with crisis and panic. The focused description of women and children being lined up, some desperately clinging to their loved ones, and others bravely facing the situation, embodies a sense of daring and peril. Moreover, the young girl standing alone, unafraid, and looking steadfastly ahead symbolizes individual courage and resolve amidst chaos. This setting naturally lends itself to a narrative centered around adventure and crisis, highlighting the human spirit\'s stoic and brave response when confronted with dire circumstances.'}]

# %% [markdown]
# ### Hybrid RAG Retrieval

# %%
from neo4j import GraphDatabase
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer
from sentence_transformers import CrossEncoder

class HybridRAGRetrieval:
    def __init__(self, neo4j_uri, neo4j_user, neo4j_password, embedding_model_name, faiss_index, metadata):
        """
        Initialize the HybridRAGRetrieval class.

        Parameters:
        - neo4j_uri: URI for the Neo4j database (e.g., "bolt://localhost:7687").
        - neo4j_user: Username for Neo4j authentication.
        - neo4j_password: Password for Neo4j authentication.
        - embedding_model_name: Name of the SentenceTransformer embedding model.
        - faiss_index: Pre-loaded Faiss index.
        - metadata: DataFrame containing metadata for the Faiss index.
        """
        self.graph_driver = GraphDatabase.driver(neo4j_uri, auth=(neo4j_user, neo4j_password))
        
        self.model = SentenceTransformer(embedding_model_name)
        self.reranker = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
        
        self.faiss_index = faiss_index
        self.metadata = metadata

    def close(self):
        """Close the Neo4j connection."""
        self.graph_driver.close()

    def graph_query(self, narrative_text):
        """
        Query the Neo4j graph for a narrative.

        Parameters:
        - narrative_text: Text to search in the graph.

        Returns:
        - A list of dictionaries containing narrative and explanation results from the graph.
        """
        with self.graph_driver.session() as session:
            query = """
            MATCH (n:Narrative)-[:HAS]->(e:Explanation)
            WHERE n.text CONTAINS $narrative_text
            RETURN n.text AS narrative, e.text AS explanation
            """
            result = session.run(query, narrative_text=narrative_text)
            return [record.data() for record in result]

    def vector_query(self, query_text, top_k=5):
        """
        Query the Faiss vector store for similar documents.

        Parameters:
        - query_text: Text query to embed and search.
        - top_k: Number of top results to retrieve.

        Returns:
        - A DataFrame containing the top-k similar documents from the vector store.
        """
        query_embedding = self.model.encode([query_text])[0]
        query_embedding = np.array([query_embedding]) 
        
        distances, indices = self.faiss_index.search(query_embedding, top_k)
        
        results = self.metadata.iloc[indices[0]].copy()
        results['distance'] = distances[0]
        return results
        
    def rerank_results(self, query_text, combined_results):
            """
            Rerank the combined results using the CrossEncoder model.

            Parameters:
            - query_text: The original query text.
            - combined_results: List of combined results from graph and vector queries.

            Returns:
            - A list of reranked results.
            """
            
            valid_results = [res for res in combined_results if isinstance(res["narrative"], str) and res["narrative"].strip()]

            input_pairs = [(query_text, res["narrative"]) for res in valid_results]

            reranker_scores = self.reranker.predict(input_pairs)

            for i, res in enumerate(valid_results):
                res["reranker_score"] = float(reranker_scores[i])

            reranked_results = sorted(valid_results, key=lambda x: x["reranker_score"], reverse=True)
            return reranked_results


    def combine_results(self, graph_results, vector_results, graph_weight=0.6, vector_weight=0.4):
        """
        Combine results from the graph and vector store.

        Parameters:
        - graph_results: Results from the graph query (list of dicts).
        - vector_results: Results from the vector store query (DataFrame).
        - graph_weight: Weight for graph-based results.
        - vector_weight: Weight for vector-based results.

        Returns:
        - A sorted list of combined results by relevance score.
        """
        combined = []

        for res in graph_results:
            combined.append({
                "source": "graph",
                "narrative": res["narrative"],
                "explanation": res["explanation"],
                "score": graph_weight
            })

        max_distance = vector_results['distance'].max() if len(vector_results) > 0 else 1
        for _, row in vector_results.iterrows():
            combined.append({
                "source": "vector",
                "narrative": row['Narrative_GPT'],
                "explanation": row['Explanation'],
                "score": vector_weight * (1 - row['distance'] / max_distance)
            })

        combined = sorted(combined, key=lambda x: x['score'], reverse=True)
        return combined

    def retrieve(self, query_text, top_k=5):
        """
        Perform a hybrid retrieval using both graph and vector stores.

        Parameters:
        - query_text: Text query to retrieve results for.
        - top_k: Number of top results to retrieve from each system.

        Returns:
        - A list of combined results from both retrieval systems.
        """
        graph_results = self.graph_query(query_text)
        vector_results = self.vector_query(query_text, top_k)

        combined_results = self.combine_results(graph_results, vector_results)
        print("combined_results",combined_results)

        reranked_results = self.rerank_results(query_text, combined_results)

        combined_results=[result for result in combined_results if result["narrative"] and isinstance(result["narrative"], str) and result["narrative"].strip()]

        unique_combined = {result['narrative']: result for result in combined_results}.values()
        return sorted(unique_combined, key=lambda x: x['score'], reverse=True)

# %%
rag = HybridRAGRetrieval(
    neo4j_uri="",
    neo4j_user="",
    neo4j_password="",
    embedding_model_name="all-MiniLM-L6-v2",
    faiss_index=index,
    metadata=metadata
)

# %%
query_text = "Adventure and crisis"
results = rag.retrieve(query_text, top_k=5)
results
# Out:
# combined_results [{'source': 'graph', 'narrative': 'Adventure and crisis (narrative) - Individual courage and stoic resolve in dire situations (subnarrative)', 'explanation': 'The passage from "The Secret Adversary" by Agatha Christie sets a scene of immediate danger and adventure as it describes the sinking of the Lusitania, a situation filled with crisis and panic. The focused description of women and children being lined up, some desperately clinging to their loved ones, and others bravely facing the situation, embodies a sense of daring and peril. Moreover, the young girl standing alone, unafraid, and looking steadfastly ahead symbolizes individual courage and resolve amidst chaos. This setting naturally lends itself to a narrative centered around adventure and crisis, highlighting the human spirit\'s stoic and brave response when confronted with dire circumstances.', 'score': 0.6}, {'source': 'vector', 'narrative': 'Adventure and crisis (narrative) - Individual courage and stoic resolve in dire situations (subnarrative)', 'explanation': 'The passage from "The Secret Adversary" by Agatha Christie sets a scene of immediate danger and adventure as it describes the sinking of the Lusitania, a situation filled with crisis and panic. The focused description of women and children being lined up, some desperately clinging to their loved ones, and others bravely facing the situation, embodies a sense of daring and peril. Moreover, the young girl standing alone, unafraid, and looking steadfastly ahead symbolizes individual courage and resolve amidst chaos. This setting naturally lends itself to a narrative centered around adventure and crisis, highlighting the human spirit\'s stoic and brave response when confronted with dire circumstances.', 'score': 0.03500521260733711}, {'source': 'vector', 'narrative': 'Disruption from an outsider (narrative) - A serene lifestyle interrupted/disturbed by an undesirable individual (subnarrative)', 'explanation': 'The narrative "Disruption from an outsider" fits the passage, as John mentions how their peaceful, productive life is tainted by Alfred Inglethorp, indicating a disturbance or a negative influence from this character filtering into their otherwise content rural existence. The subnarrative, "A serene lifestyle interrupted/disturbed by an undesirable individual," highlights how John and his family engage pleasantly in daily farming activities and volunteer work, creating a picture of rural idyll which is abruptly marred by the mere mention of Inglethorp, suggesting his presence or actions are unwelcome and disrupt the tranquility of their lives.', 'score': 0.02674528662314093}, {'source': 'vector', 'narrative': 'Frugality and resourcefulness in wartime (narrative) - Household commits to waste reduction and recycling (subnarrative)', 'explanation': 'The narrative of "Frugality and resourcefulness in wartime" along with the sub-narrative "Household commits to waste reduction and recycling" is derived from the passage that emphasizes setting an example of economy by saving every scrap of waste, signifying a strict management of resources. This reflects the overarching theme of careful and mindful conservation during difficult times, specifically a war period, where the household ensures nothing is wasted, representing a broader message of prudence and adaptation.', 'score': 0.004614672530862141}, {'source': 'vector', 'narrative': 'Tension and distrust in social relations (narrative) - Suspicions and warnings about character motives (subnarrative)', 'explanation': 'The narrative "Tension and distrust in social relations" is derived from the interactions and dialogue between the characters, where warnings are issued about Farmer Raikes and there is clear animosity expressed by Miss Howard towards others\' views on her accusations. The subnarrative "Suspicions and warnings about character motives" is supported by the explicit suspicions Miss Howard voices regarding the intentions of those surro ...
# [{'source': 'vector',
#   'narrative': 'Adventure and crisis (narrative) - Individual courage and stoic resolve in dire situations (subnarrative)',
#   'explanation': 'The passage from "The Secret Adversary" by Agatha Christie sets a scene of immediate danger and adventure as it describes the sinking of the Lusitania, a situation filled with crisis and panic. The focused description of women and children being lined up, some desperately clinging to their loved ones, and others bravely facing the situation, embodies a sense of daring and peril. Moreover, the young girl standing alone, unafraid, and looking steadfastly ahead symbolizes individual courage and resolve amidst chaos. This setting naturally lends itself to a narrative centered around adventure and crisis, highlighting the human spirit\'s stoic and brave response when confronted with dire circumstances.',
#   'score': 0.03500521260733711},
#  {'source': 'vector',
#   'narrative': 'Disruption from an outsider (narrative) - A serene lifestyle interrupted/disturbed by an undesirable individual (subnarrative)',
#   'explanation': 'The narrative "Disruption from an outsider" fits the passage, as John mentions how their peaceful, productive life is tainted by Alfred Inglethorp, indicating a disturbance or a negative influence from this character filtering into their otherwise content rural existence. The subnarrative, "A serene lifestyle interrupted/disturbed by an undesirable individual," highlights how John and his family engage pleasantly in daily farming activities and volunteer work, creating a picture of rural idyll which is abruptly marred by the mere mention of Inglethorp, suggesting his presence or actions are unwelcome and disrupt the tranquility of their lives.',
#   'score': 0.02674528662314093},
#  {'source': 'vector',
#   'narrative': 'Frugality and resourcefulness in wartime (narrative) - Household commits to waste reduction and recycling (subnarrative)',
#   'explanation': 'The narrative of "Frugality and resourcefulness in wartime" along with the sub-narrative "Household commits to waste reduction and recycling" is derived from the passage that emphasizes setting an example of economy by saving every scrap of waste, signifying a strict management of resources. This reflects the overarching theme of careful and mindful conservation during difficult times, specifically a war period, where the household ensures nothing is wasted, representing a broader message of prudence and adaptation.',
#   'score': 0.004614672530862141},
#  {'source': 'vector',
#   'narrative': 'Tension and distrust in social relations (narrative) - Suspicions and warnings about character motives (subnarrative)',
#   'explanation': 'The narrative "Tension and distrust in social relations" is derived from the interactions and dialogue between the characters, where warnings are issued about Farmer Raikes and there is clear animosity expressed by Miss Howard towards others\' views on her accusations. The subnarrative "Suspicions and warnings about character motives" is supported by the explicit suspicions Miss Howard voices regarding the intentions of those surrounding Mrs. Inglethorp, describing them as "sharks" trying to exploit her, which indicates underlying motifs of deceit and self-interest among the characters. These themes create a narrative around the potential dangers and mistrust in their relationships.',
#   'score': 0.0017998060166457997},
#  {'source': 'vector',
#   'narrative': 'Social interactions and observations (narrative) - Personal dynamics and relationships explored (subnarrative)',
#   'explanation': 'The chosen narrative, "Social interactions and observations," captures the essence of the passage where the characters are engaged in various social interactions, such as chatting on the balcony, discussing their day, and a surprising encounter with a familiar person at the post office. These interactions help unveil personal dynamics and relationships among the characters, which is portrayed through their conversation styles and the narrator\'s observations. Thus, the subnarrative, "Personal dynamics and relationships explored," reflects the focus on understanding and discovering the deeper connections and social behaviors between the characters, providing insight into their personalities and relationships.',
#   'score': 0.0}]

# %%
query_text = "Crisis and love"
results = rag.retrieve(query_text, top_k=5)
results
# Out:
# combined_results [{'source': 'vector', 'narrative': 'Frugality and resourcefulness in wartime (narrative) - Household commits to waste reduction and recycling (subnarrative)', 'explanation': 'The narrative of "Frugality and resourcefulness in wartime" along with the sub-narrative "Household commits to waste reduction and recycling" is derived from the passage that emphasizes setting an example of economy by saving every scrap of waste, signifying a strict management of resources. This reflects the overarching theme of careful and mindful conservation during difficult times, specifically a war period, where the household ensures nothing is wasted, representing a broader message of prudence and adaptation.', 'score': 0.043202144158190015}, {'source': 'vector', 'narrative': 'Revealing personal conflicts and consequences (narrative) - Tension in relationships leading to decisive actions (subnarrative)', 'explanation': 'The narrative of "Revealing personal conflicts and consequences" is chosen because the passage delves into a dramatic, interpersonal conflict among characters, which directly leads to someone leaving abruptly with strong emotions displayed. The subnarrative of "Tension in relationships leading to decisive actions" reflects the specific reasons for the departure, highlighting a heated argument about motives, age differences, and monetary matters, which ultimately compel one character to take bold, decisive action by leaving the scene and expressing her discontent firmly.', 'score': 0.007682107849683906}, {'source': 'vector', 'narrative': 'Disruption from an outsider (narrative) - A serene lifestyle interrupted/disturbed by an undesirable individual (subnarrative)', 'explanation': 'The narrative "Disruption from an outsider" fits the passage, as John mentions how their peaceful, productive life is tainted by Alfred Inglethorp, indicating a disturbance or a negative influence from this character filtering into their otherwise content rural existence. The subnarrative, "A serene lifestyle interrupted/disturbed by an undesirable individual," highlights how John and his family engage pleasantly in daily farming activities and volunteer work, creating a picture of rural idyll which is abruptly marred by the mere mention of Inglethorp, suggesting his presence or actions are unwelcome and disrupt the tranquility of their lives.', 'score': 0.007322894686336579}, {'source': 'vector', 'narrative': 'Tension and distrust in social relations (narrative) - Suspicions and warnings about character motives (subnarrative)', 'explanation': 'The narrative "Tension and distrust in social relations" is derived from the interactions and dialogue between the characters, where warnings are issued about Farmer Raikes and there is clear animosity expressed by Miss Howard towards others\' views on her accusations. The subnarrative "Suspicions and warnings about character motives" is supported by the explicit suspicions Miss Howard voices regarding the intentions of those surrounding Mrs. Inglethorp, describing them as "sharks" trying to exploit her, which indicates underlying motifs of deceit and self-interest among the characters. These themes create a narrative around the potential dangers and mistrust in their relationships.', 'score': 0.0020729793113276164}, {'source': 'vector', 'narrative': 'Negotiation and subterfuge (narrative) - Strategies of deception or persuasion (subnarrative)', 'explanation': 'The narrative of "Negotiation and subterfuge" is derived from the interaction between Tuppence and Whittington, where Tuppence cleverly manipulates the conversation to gain an advantage. She proposes a payment arrangement that initially sounds like blackmail but softens it by framing it as a payment for services in advance, a tactic aimed to persuade without arousing too much suspicion. Whittington\'s response oscillates between suspicion and reluctant admiration, indicating that he\'s aware he\'s being maneuvered but can\'t pinpoint the decei ...
# [{'source': 'vector',
#   'narrative': 'Frugality and resourcefulness in wartime (narrative) - Household commits to waste reduction and recycling (subnarrative)',
#   'explanation': 'The narrative of "Frugality and resourcefulness in wartime" along with the sub-narrative "Household commits to waste reduction and recycling" is derived from the passage that emphasizes setting an example of economy by saving every scrap of waste, signifying a strict management of resources. This reflects the overarching theme of careful and mindful conservation during difficult times, specifically a war period, where the household ensures nothing is wasted, representing a broader message of prudence and adaptation.',
#   'score': 0.043202144158190015},
#  {'source': 'vector',
#   'narrative': 'Revealing personal conflicts and consequences (narrative) - Tension in relationships leading to decisive actions (subnarrative)',
#   'explanation': 'The narrative of "Revealing personal conflicts and consequences" is chosen because the passage delves into a dramatic, interpersonal conflict among characters, which directly leads to someone leaving abruptly with strong emotions displayed. The subnarrative of "Tension in relationships leading to decisive actions" reflects the specific reasons for the departure, highlighting a heated argument about motives, age differences, and monetary matters, which ultimately compel one character to take bold, decisive action by leaving the scene and expressing her discontent firmly.',
#   'score': 0.007682107849683906},
#  {'source': 'vector',
#   'narrative': 'Disruption from an outsider (narrative) - A serene lifestyle interrupted/disturbed by an undesirable individual (subnarrative)',
#   'explanation': 'The narrative "Disruption from an outsider" fits the passage, as John mentions how their peaceful, productive life is tainted by Alfred Inglethorp, indicating a disturbance or a negative influence from this character filtering into their otherwise content rural existence. The subnarrative, "A serene lifestyle interrupted/disturbed by an undesirable individual," highlights how John and his family engage pleasantly in daily farming activities and volunteer work, creating a picture of rural idyll which is abruptly marred by the mere mention of Inglethorp, suggesting his presence or actions are unwelcome and disrupt the tranquility of their lives.',
#   'score': 0.007322894686336579},
#  {'source': 'vector',
#   'narrative': 'Tension and distrust in social relations (narrative) - Suspicions and warnings about character motives (subnarrative)',
#   'explanation': 'The narrative "Tension and distrust in social relations" is derived from the interactions and dialogue between the characters, where warnings are issued about Farmer Raikes and there is clear animosity expressed by Miss Howard towards others\' views on her accusations. The subnarrative "Suspicions and warnings about character motives" is supported by the explicit suspicions Miss Howard voices regarding the intentions of those surrounding Mrs. Inglethorp, describing them as "sharks" trying to exploit her, which indicates underlying motifs of deceit and self-interest among the characters. These themes create a narrative around the potential dangers and mistrust in their relationships.',
#   'score': 0.0020729793113276164},
#  {'source': 'vector',
#   'narrative': 'Negotiation and subterfuge (narrative) - Strategies of deception or persuasion (subnarrative)',
#   'explanation': 'The narrative of "Negotiation and subterfuge" is derived from the interaction between Tuppence and Whittington, where Tuppence cleverly manipulates the conversation to gain an advantage. She proposes a payment arrangement that initially sounds like blackmail but softens it by framing it as a payment for services in advance, a tactic aimed to persuade without arousing too much suspicion. Whittington\'s response oscillates between suspicion and reluctant admiration, indicating that he\'s aware he\'s being maneuvered but can\'t pinpoint the deceit, highlighting elements of both negotiation and subterfuge. This is supported by Tuppence\'s admittance of her love for money and her moralization about life\'s surprises, underscoring the strategy of deception or persuasion used within their exchange.',
#   'score': 0.0}]

# %%
data_conan=pd.read_csv("arthur_conan_narrative.csv")
#data_conan=data_conan.dropna()
data_conan.head()
# Out:
#    Unnamed: 0                                           Document  \
# 0           0  The Adventure of the Devil's Foot By Sir Arthu...
# 1           2  Tales of Terror and Mystery By Sir Arthur Cona...
# 2           4  BEYOND THE CITY By Arthur Conan Doyle CHAPTER ...
# 3           6  UNCLE BERNAC A MEMORY OF THE EMPIRE CONTENTS C...
# 4           8  THE CABMAN'S STORY The Mysteries of a London "...
#
#                                            Narrative                  Author  \
# 0  Detective work and characters in Sherlock Holm...  Sir Arthur Conan Doyle
# 1         Reading habits and preferences of a writer  Sir Arthur Conan Doyle
# 2               Castles and Abbeys in a Coastal Town  Sir Arthur Conan Doyle
# 3  French nobility and intrigue in the Napoleonic...  Sir Arthur Conan Doyle
# 4               Clothing and Appearance Descriptions  Sir Arthur Conan Doyle
#
#                                 Book  \
# 0  The Adventure of the Devil's Foot
# 1        Tales of Terror and Mystery
# 2                    Beyond the City
# 3                       Uncle Bernac
# 4                 The Cabman's Story
#
#                                        Narrative_GPT  \
# 0  Privacy vs. recognition (narrative) - Preferen...
# 1  Exploration of the unexplained and sinister (n...
# 2  Introduction to the neighborhood and observati...
# 3  Exploration of memory and history (narrative) ...
# 4  Embarking on a family outing with overcast ski...
#
#                                          Explanation  \
# 0  The passage from "The Adventure of the Devil's...
# 1  The passage sets up a narrative that delves in...
# 2  The narrative "Introduction to the neighborhoo...
# 3  The narrative of "Exploration of memory and hi...
# 4  The narrative "Embarking on a family outing wi...
#
#       Explanation_mistral.mixtral-8x7b-instruct-v0:1  \
# 0   The passage from "The Adventure of the Devil'...
# 1   The narrative in the passage from "Tales of T...
# 2   The narrative of the passage from "Beyond the...
# 3   Narrative: Revisiting the Past and Inherited ...
# 4   The narrative present in the passage from "Th...
#
#    Explanation_us.meta.llama3-1-8b-instruct-v1:0  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Explanation_arn:aws:bedrock:us-east-1:594264953269:inference-profile/us.meta.llama3-1-8b-instruct-v1:0
# 0   Here's a possible reasoning for the passage "...
# 1   Based on the passage from "Tales of Terror an...
# 2   The passage "BEYOND THE CITY" by Arthur Conan...
# 3   Here are a few sentences explaining why the p...
# 4   The passage has this narrative: "Embarking on...

# %% [markdown]
# ### Task 4: Narrative Explanation Generation

# %% [markdown]
# #### GPT4 Data

# %%
import os
from openai import AzureOpenAI
import openai

# %%
api_key = os.getenv("AZURE_OPENAI_API_KEY")
api_base = os.getenv("AZURE_OPENAI_API_BASE")
api_version = os.getenv("AZURE_OPENAI_API_VERSION")
openai.api_type = "azure"
openai.api_key = api_key
api_base = api_base
api_version = api_version

deployment_name = "gpt-4"

# %%
def get_explanation(document, narrative,book,author,examples):
    
    """
    Function to provide reasoning for the given question using Azure OpenAI.
    """
    filtered_examples = [{"narrative": example["narrative"], "explanation": example["explanation"]} for example in examples]
    filtered_examples=filtered_examples[:3]
    
    question=f"""Give me few senence reasoning Why the passage  <passage>{document} </passage> from  <title>{book}</title> of {author} has this narrative <narrative>{narrative}</narrative>

    Use the following examples to generate the reasoning:

    Examples:

    {filtered_examples}
 
    """

    
    
    try:
        client = AzureOpenAI(
            api_version=api_version,
            azure_endpoint=api_base,
        )

        completion = client.chat.completions.create(
            model=deployment_name,  
            messages=[
                {
                    "role": "system",
                    "content": "You are a reasoning assistant that explains in a shot sentecte based on the question asked",
                },
                {"role": "user",
                 "content": question
                }
            ]
        )

        explanation = completion.choices[0].message.content
        

        
        return explanation
    
    except Exception as e:
        return f"Error: {e}"

# %%
# rag = HybridRAGRetrieval(
#     neo4j_uri="bolt://localhost:7687",
#     neo4j_user="neo4j",
#     neo4j_password="Test@123",
#     embedding_model_name="all-MiniLM-L6-v2",
#     faiss_index=index,
#     metadata=metadata
# )

# explanations = []

# for index, row in data_conan.iterrows():
#     document = row['Document']
#     narrative_test = row['Narrative_GPT']
#     book = row['Book']
#     author = row['Author']

#     print(narrative_test)
    
#     results = rag.retrieve(narrative_test, top_k=5)
#     explanation = get_explanation(document, narrative_test, book, author, results)
#     explanations.append(explanation)

# data_conan['Explanation'] = explanations
# data_conan.to_csv("arthur_conan_narrative_with_explaination.csv", index=False)

# %%
data_conan.head()["Explanation"][0]
# Out:
# 'The passage from "The Adventure of the Devil\'s Foot" highlights Sherlock Holmes\' preference for privacy over public recognition, despite his successful career as a detective. Holmes\' distaste for applause and his habit of letting orthodox officials take the credit for his work underline the narrative of favoring anonymity over acclaim. His actions and decisions, as narrated by his friend and chronicler, emphasize a unique characteristic of Holmes, setting a tone that aligns with the broader theme of privacy versus recognition. This narrative resonates with Holmes\' mysterious personality and his unconventional approach to his profession, capturing the essence of a character who seeks satisfaction in intellectual challenge rather than public validation.'

# %% [markdown]
# #### Bedrock - Mistral 8*7B Instruct, LlaMA , Claude, Titan

# %%
import boto3
import logging
from botocore.exceptions import ClientError
from botocore.config import Config
import time

import json
boto3.set_stream_logger('botocore', level='INFO')

# %%
class BedrockWrapper:
  
    def __init__(self,service,region):
        
        """ Initiates the bedrock client and runtime
        """
        boto_config = Config(
            retries={
                'max_attempts': 100,  
                'mode': 'adaptive'
            }
        )
        self.bedrock_client = boto3.client(service_name=service, region_name=region,config=boto_config)
        self.bedrock_runtime = boto3.client('bedrock-runtime')

    def list_foundation_models(self):
        """ List the foundational models available
        """
        response = self.bedrock_client.list_foundation_models()
        models = response["modelSummaries"]
        print(f"Got {len(models)} foundation models.", models)


    def set_model(self,model_id):
        """ sets the generative AI models Id to be used
        """
        self.model_id=model_id

    def generate_body(self, prompt, params):


        """Sets model parameter and prompt."""
        # Create a single string for the dialogue


        if(self.model_id=="mistral.mixtral-8x7b-instruct-v0:1"):
            formatted_prompt = f"<s>[INST] {prompt} [/INST]"
            native_request = {
                "prompt": formatted_prompt,
                "max_tokens": 512,
                "temperature": 0.5,
            }

            return json.dumps(native_request).encode('utf-8')
        elif(self.model_id=="anthropic.claude-3-5-sonnet-20240620-v1:0"):

            native_request={
                    "anthropic_version": "bedrock-2023-05-31",
                    "max_tokens": 512,
                    "messages": [
                    {
                        "role": "user",
                        "content": [
                        {
                            "type": "text",
                            "text": prompt
                        }
                        ]
                    }]
            }

            print(self.model_id,"      ",native_request)


            return json.dumps(native_request).encode('utf-8')
        
        elif(self.model_id=="arn:aws:bedrock:us-east-1:inference-profile/us.meta.llama3-1-8b-instruct-v1:0"):
            formatted_prompt = f"""
            <|begin_of_text|><|start_header_id|>user<|end_header_id|>
            {prompt}
            <|eot_id|>
            <|start_header_id|>assistant<|end_header_id|>
            """

            native_request = {
                "prompt": formatted_prompt,
                "max_gen_len": 512,
                "temperature": 0.5,
            }

            return json.dumps(native_request).encode('utf-8')
        elif(self.model_id=="amazon.titan-text-express-v1"):

            native_request = {
                "inputText": prompt,
                "textGenerationConfig": {
                    "maxTokenCount": 512,
                    "temperature": 0.5,
                },
            }

            # Convert the native request to JSON.
            return json.dumps(native_request).encode('utf-8')



    def invoke_model(self,body):
        """calls the model and get response string
        """
      
        accept = 'application/json'
        contentType = 'application/json'
        print(self.model_id)
        response=None
        arn="arn:aws:bedrock:us-east-1:inference-profile/us.meta.llama3-1-8b-instruct-v1:0"

        response = self.bedrock_runtime.invoke_model(body=body, modelId= self.model_id, accept=accept, contentType=contentType)

        if(self.model_id=="mistral.mixtral-8x7b-instruct-v0:1"):
            model_response = json.loads(response["body"].read())

            # Extract and print the response text.
            response_text = model_response["outputs"][0]["text"]
            print(response_text)

            return response_text
        elif(self.model_id=="anthropic.claude-3-5-sonnet-20240620-v1:0"):
            model_response = json.loads(response["body"].read())
            response_text = model_response["content"][0]["text"]
            print(response_text)
            return response_text
        elif(self.model_id=="arn:aws:bedrock:us-east-1:inference-profile/us.meta.llama3-1-8b-instruct-v1:0"):
            model_response = json.loads(response["body"].read())
            # Extract and print the response text.
            response_text = model_response["generation"]
            print(response_text)
            return response_text
        elif(self.model_id=="amazon.titan-text-express-v1"):
            model_response = json.loads(response["body"].read())

            # Extract and print the response text.
            response_text = model_response["results"][0]["outputText"]
            print(response_text)
            return response_text

# %%
def get_explanation_bedrock(bedrock,document, narrative,book,author,examples):
    
    """
    Function to provide reasoning for the given question using Azure OpenAI.
    """
    filtered_examples = [{"narrative": example["narrative"], "explanation": example["explanation"]} for example in examples]
    filtered_examples=filtered_examples[:3]
    
    prompt=f"""Give me few senence reasoning Why the passage  <passage>{document} </passage> from  <title>{book}</title> of {author} has this narrative <narrative>{narrative}</narrative>

    Use the following examples to generate the reasoning:

    Examples:

    {filtered_examples}
 
    """

    params={
        "max_tokens": 1000,
        "temperature": 0.1,
    }


    
    
    try:
        body=bedrock.generate_body(prompt,params)

        result=bedrock.invoke_model(body)

        
        return result
    
    except Exception as e:
        return f"Error: {e}"

# %%
# rag = HybridRAGRetrieval(
#     neo4j_uri="",
#     neo4j_user="",
#     neo4j_password="",
#     embedding_model_name="all-MiniLM-L6-v2",
#     faiss_index=index,
#     metadata=metadata
# )
# bedrock=BedrockWrapper("bedrock","us-east-1")

# #bedrock.list_foundation_models()

# modelId = "mistral.mixtral-8x7b-instruct-v0:1"

# bedrock.set_model(modelId)



# explanations = []

# for index, row in data_conan.iterrows():
#     document = row['Document']
#     narrative_test = row['Narrative_GPT']
#     book = row['Book']
#     author = row['Author']

#     print(narrative_test)
    
#     results = rag.retrieve(narrative_test, top_k=5)
#     explanation = get_explanation_bedrock(bedrock,document, narrative_test, book, author, results)
#     explanations.append(explanation)

# data_conan['Explanation_'+modelId] = explanations
#data_conan.to_csv("arthur_conan_narrative_with_explaination.csv", index=False)

# %%
# rag = HybridRAGRetrieval(
#     neo4j_uri="",
#     neo4j_user="",
#     neo4j_password="",
#     embedding_model_name="all-MiniLM-L6-v2",
#     faiss_index=index,
#     metadata=metadata
# )
# bedrock=BedrockWrapper("bedrock","us-east-1")

# #bedrock.list_foundation_models()

# modelId = "anthropic.claude-3-5-sonnet-20240620-v1:0"

# bedrock.set_model(modelId)



# explanations = []

# for index, row in data_conan.iterrows():
#     document = row['Document']
#     narrative_test = row['Narrative_GPT']
#     book = row['Book']
#     author = row['Author']

#     print(narrative_test)
    
#     results = rag.retrieve(narrative_test, top_k=5)
#     explanation = get_explanation_bedrock(bedrock,document, narrative_test, book, author, results)
#     explanations.append(explanation)
#     time.sleep(10)
#     print(explanations[-1])

# data_conan['Explanation_'+modelId] = explanations
# data_conan.to_csv("arthur_conan_narrative_with_explaination.csv", index=False)

# %%
# rag = HybridRAGRetrieval(
#     neo4j_uri="",
#     neo4j_user="",
#     neo4j_password="",
#     embedding_model_name="all-MiniLM-L6-v2",
#     faiss_index=index,
#     metadata=metadata
# )
# bedrock=BedrockWrapper("bedrock","us-east-1")

# #bedrock.list_foundation_models()

# modelId = "arn:aws:bedrock:us-east-1:inference-profile/us.meta.llama3-1-8b-instruct-v1:0"


# bedrock.set_model(modelId)



# explanations = []

# for index, row in data_conan.iterrows():
#     document = row['Document']
#     narrative_test = row['Narrative_GPT']
#     book = row['Book']
#     author = row['Author']

#     print(narrative_test)
    
#     results = rag.retrieve(narrative_test, top_k=5)
#     explanation = get_explanation_bedrock(bedrock,document, narrative_test, book, author, results)
#     explanations.append(explanation)
#     # time.sleep(10)
#     print(explanations[-1])

# data_conan['Explanation_'+modelId] = explanations
# data_conan.to_csv("arthur_conan_narrative_with_explaination.csv", index=False)

# %%
rag = HybridRAGRetrieval(
    neo4j_uri="",
    neo4j_user="",
    neo4j_password="",
    embedding_model_name="all-MiniLM-L6-v2",
    faiss_index=index,
    metadata=metadata
)
bedrock=BedrockWrapper("bedrock","us-east-1")

#bedrock.list_foundation_models()

modelId = "amazon.titan-text-express-v1"


bedrock.set_model(modelId)



explanations = []

for index, row in data_conan.iterrows():
    document = row['Document']
    narrative_test = row['Narrative_GPT']
    book = row['Book']
    author = row['Author']

    print(narrative_test)
    
    results = rag.retrieve(narrative_test, top_k=5)
    explanation = get_explanation_bedrock(bedrock,document, narrative_test, book, author, results)
    explanations.append(explanation)
    # time.sleep(10)
    print(explanations[-1])

data_conan['Explanation_'+modelId] = explanations
data_conan.to_csv("arthur_conan_narrative_with_explaination.csv", index=False)
# Out:
# Privacy vs. recognition (narrative) - Preference for anonymity over public acclaim (subnarrative)
# combined_results [{'source': 'vector', 'narrative': nan, 'explanation': 'The passage from "The Secret Adversary" involves a playful and speculative conversation between Tommy and Tuppence about starting an unusual business venture that would involve them in crimes like stealing, albeit indirectly. The narrative revolves around the ethical contemplations and the practical aspect of getting involved in morally dubious activities not for personal gain, but as a hired service. Tuppence rationalizes the moral aspect distinguishing personal crime from being hired to commit a crime, while Tommy points out the practical risks, like getting caught. The passage showcases their adventurous spirit and willingness to delve into risky ventures, pegging them as potential \'young adventurers.\' This sets up the narrative tone for possibly engaging in risky, morally ambiguous activities, emphasizing a blend of adventure, humor, and ethical debate integral to their characters and the story.', 'score': 0.04145002187476896}, {'source': 'vector', 'narrative': 'Elegant social gathering and communication (narrative) - Subtle dynamics of social hierarchy and influence (subnarrative)', 'explanation': 'The passage presents an elegant social setting where characters interact with grace and subtlety, hinting at deeper personal and social dynamics. The description of Mrs. Cavendish, the manner in which she hosts the gathering, and the conversation about writing letters to various high-society individuals all point to a nuanced social ladder and the influence wielded by individuals within it. The poised yet powerful persona of Mrs. Cavendish juxtaposed with the well-connected guests discussing social engagements vividly paints a narrative of navigating social hierarchies with finesse.', 'score': 0.039779452020036035}, {'source': 'vector', 'narrative': 'Narrative Setting (narrative) - An old acquaintance and a convalescent soldier (subnarrative)', 'explanation': "The passage introduces the setting by discussing the protagonist's return from the war and subsequent recuperation, leading to a chance encounter with an old acquaintance, John Cavendish. This context sets the stage for the unfolding events at Styles, an estate familiar to the protagonist from childhood but now visited under different circumstances. The rekindling of relationships and the backdrop of recovery from personal trauma contribute to the foundational elements of the narrative, emphasizing themes of reconnecting and uncovering truths from the past within a familiar yet changed environment.", 'score': 0.03440587096423675}, {'source': 'vector', 'narrative': 'Social gathering planning (narrative) - Dislike and distrust evident (subnarrative)', 'explanation': 'The narrative of "Social gathering planning" is derived from the mention of Mrs. Inglethorp organizing a forthcoming bazaar, which indicates a social event being arranged. The subnarrative of "Dislike and distrust evident" stems from the narrator\'s immediate and firm rooted dislike towards Mr. Inglethorp, suggesting an underlying tension or mistrust towards his character from the onset. These narratives reflect key themes and tones introduced in the passage relating to social interaction and personal sentiments.', 'score': 0.003944902345225332}, {'source': 'vector', 'narrative': 'Social dynamics and economic challenges (narrative) - Post-war adjustment and financial struggles (subnarrative)', 'explanation': 'The passage portrays Tommy and Tuppence engaging in a light-hearted conversation that reveals deeper themes of post-war societal dynamics and economic difficulties. They discuss being "demobbed," a term referencing demobilization or discharge from military service, suggesting a return to civilian life after World War I. This background indicates an adjustment period that many faced after the war. Additionally, Tommy refers to the quick spending of his gratuity, hinting at the financial struggles they\'re encountering, which is under ...
# amazon.titan-text-express-v1
# The passage highlights a narrative of an elegant social gathering and communication, where characters engage in subtle dynamics of social hierarchy and influence. The description of Mrs. Cavendish's hosting of the gathering, along with the conversation about writing letters to various high-society individuals, suggests a nuanced social ladder and the influence wielded by individuals within it. The poised yet powerful persona of Mrs. Cavendish juxtaposed with the well-connected guests discussing social engagements vividly paints a narrative of navigating social hierarchies with finesse.
# The passage highlights a narrative of an elegant social gathering and communication, where characters engage in subtle dynamics of social hierarchy and influence. The description of Mrs. Cavendish's hosting of the gathering, along with the conversation about writing letters to various high-society individuals, suggests a nuanced social ladder and the influence wielded by individuals within it. The poised yet powerful persona of Mrs. Cavendish juxtaposed with the well-connected guests discussing social engagements vividly paints a narrative of navigating social hierarchies with finesse.
# Exploration of the unexplained and sinister (narrative) - Blurring the lines between reality and elaborate hoax (subnarrative)
# combined_results [{'source': 'vector', 'narrative': 'Narrative Setting (narrative) - An old acquaintance and a convalescent soldier (subnarrative)', 'explanation': "The passage introduces the setting by discussing the protagonist's return from the war and subsequent recuperation, leading to a chance encounter with an old acquaintance, John Cavendish. This context sets the stage for the unfolding events at Styles, an estate familiar to the protagonist from childhood but now visited under different circumstances. The rekindling of relationships and the backdrop of recovery from personal trauma contribute to the foundational elements of the narrative, emphasizing themes of reconnecting and uncovering truths from the past within a familiar yet changed environment.", 'score': 0.05447774440385955}, {'source': 'vector', 'narrative': 'Change and Uncertainty (narrative) - Shift in atmosphere and relationships (subnarrative)', 'explanation': 'The passage described a sense of distress brought about by Evelyn Howard\'s absence, who previously brought a sense of security. This change, represented by Evelyn\'s departure and the emergence of Dr. Bauerstein as a suspicious figure, introduces a suspicious and unsettling atmosphere. The "premonition of approaching evil" encapsulates this shift towards uncertainty and distrust, marked prominently by the altered dynamics in relationships and environment, once comforted by Evelyn\'s presence. This establishes a narrative of change and evolving uncertainties as the characters navigate their new dynamics and suspicions.', 'score': 0.040653419254994286}, {'source': 'vector', 'narrative': 'Engaging in mystery and speculative deduction (narrative) - Discussion on crime detection and undiscovered offenses (subnarrative)', 'explanation': 'The passage revolves around a conversation concerning the awareness and perception of crimes within a close-knit group, like a family. Miss Howard and the others debate the detectability of criminals and the nature of murder, wherein Miss Howard insists that family members or those intimately involved would inherently recognize the wrongdoer without formal proof. This belief in intuitive detection amid everyday familiarity feeds into the narrative of engaging with mystery and speculative deduction. The specific mention of poisoning and unrecognized crimes by Mrs. Cavendish, points to the nuanced discussion on overlooked or subtle criminal acts, further enriching the subnarrative that focuses on crime detection and undiscovered offenses.', 'score': 0.039774545777274864}, {'source': 'vector', 'narrative': 'Family tensions and secrets (narrative) - Suspicion and concealment in relationships (subnarrative)', 'explanation': 'The chosen narrative of "Family tensions and secrets" with the subnarrative of "Suspicion and concealment in relationships" is deduced from the description of interpersonal dynamics within the passage. The dialogue hints at undisclosed conflicts, particularly in the lines where characters discussed someone discovering another\'s true nature, hinting at concealment and eventual revelation. The strain is evident when characters express hopes that a family member will end relations with the suspected individual, exhibiting the tension. Further, the unusual behavior at dinner, particularly with different characters showing signs of agitation and altered routines (like Inglethorp not attending to his wife as usual) supports the theme of underlying secrets affecting relationships, leading to a palpable tension.', 'score': 0.00031187510573800205}, {'source': 'vector', 'narrative': 'Adventure and crisis (narrative) - Individual courage and stoic resolve in dire situations (subnarrative)', 'explanation': 'The passage from "The Secret Adversary" by Agatha Christie sets a scene of immediate danger and adventure as it describes the sinking of the Lusitania, a situation filled with crisis and panic. The focused description of women and children being lined up, some d ...
# amazon.titan-text-express-v1
#  The passage discusses the narrative setting, characterized by the protagonist's return from the war and subsequent recuperation, leading to a chance encounter with an old acquaintance, John Cavendish. The rekindling of relationships and the backdrop of recovery from personal trauma contribute to the foundational elements of the narrative, emphasizing themes of reconnecting and uncovering truths from the past within a familiar yet changed environment. The passage also introduces a sense of distress brought about by Evelyn Howard's absence, who previously brought a sense of security. This shift, represented by Evelyn's departure and the emergence of Dr. Bauerstein as a suspicious figure, introduces a suspicious and unsettling atmosphere. The passage discusses the shift towards uncertainty and distrust, marked prominently by the altered dynamics in relationships and environment, once comforted by Evelyn's presence. This establishes a narrative of change and evolving uncertainties as the characters navigate their new dynamics and suspicions. The passage revolves around a conversation concerning the awareness and perception of crimes within a close-knit group, like a family. Miss Howard and the others debate the detectability of criminals and the nature of murder, wherein Miss Howard insists that family members or those intimately involved would inherently recognize the wrongdoer without formal proof. This belief in intuitive detection amid everyday familiarity feeds into the narrative of engaging with mystery and speculative deduction. The specific mention of poisoning and unrecognized crimes by Mrs. Cavendish points to the nuanced discussion on overlooked or subtle criminal acts, further enriching the subnarrative that focuses on crime detection and undiscovered offenses.
#  The passage discusses the narrative setting, characterized by the protagonist's return from the war and subsequent recuperation, leading to a chance encounter with an old acquaintance, John Cavendish. The rekindling of relationships and the backdrop of recovery from personal trauma contribute to the foundational elements of the narrative, emphasizing themes of reconnecting and uncovering truths from the past within a familiar yet changed environment. The passage also introduces a sense of distress brought about by Evelyn Howard's absence, who previously brought a sense of security. This shift, represented by Evelyn's departure and the emergence of Dr. Bauerstein as a suspicious figure, introduces a suspicious and unsettling atmosphere. The passage discusses the shift towards uncertainty and distrust, marked prominently by the altered dynamics in relationships and environment, once comforted by Evelyn's presence. This establishes a narrative of change and evolving uncertainties as the characters navigate their new dynamics and suspicions. The passage revolves around a conversation concerning the awareness and perception of crimes within a close-knit group, like a family. Miss Howard and the others debate the detectability of criminals and the nature of murder, wherein Miss Howard insists that family members or those intimately involved would inherently recognize the wrongdoer without formal proof. This belief in intuitive detection amid everyday familiarity feeds into the narrative of engaging with mystery and speculative deduction. The specific mention of poisoning and unrecognized crimes by Mrs. Cavendish points to the nuanced discussion on overlooked or subtle criminal acts, further enriching the subnarrative that focuses on crime detection and undiscovered offenses.
# Introduction to the neighborhood and observation (narrative) - Adjusting to new neighbors and neighborhood dynamics (subnarrative)
# combined_results [{'source': 'vector', 'narrative': 'Disruption from an outsider (narrative) - A serene lifestyle interrupted/disturbed by an undesirable individual (subnarrative)', 'explanation': 'The narrative "Disruption from an outsider" fits the passage, as John mentions how their peaceful, productive life is tainted by Alfred Inglethorp, indicating a disturbance or a negative influence from this character filtering into their otherwise content rural existence. The subnarrative, "A serene lifestyle interrupted/disturbed by an undesirable individual," highlights how John and his family engage pleasantly in daily farming activities and volunteer work, creating a picture of rural idyll which is abruptly marred by the mere mention of Inglethorp, suggesting his presence or actions are unwelcome and disrupt the tranquility of their lives.', 'score': 0.05340089267377275}, {'source': 'vector', 'narrative': 'Frugality and resourcefulness in wartime (narrative) - Household commits to waste reduction and recycling (subnarrative)', 'explanation': 'The narrative of "Frugality and resourcefulness in wartime" along with the sub-narrative "Household commits to waste reduction and recycling" is derived from the passage that emphasizes setting an example of economy by saving every scrap of waste, signifying a strict management of resources. This reflects the overarching theme of careful and mindful conservation during difficult times, specifically a war period, where the household ensures nothing is wasted, representing a broader message of prudence and adaptation.', 'score': 0.022196002564830144}, {'source': 'vector', 'narrative': 'Social interactions and observations (narrative) - Personal dynamics and relationships explored (subnarrative)', 'explanation': 'The chosen narrative, "Social interactions and observations," captures the essence of the passage where the characters are engaged in various social interactions, such as chatting on the balcony, discussing their day, and a surprising encounter with a familiar person at the post office. These interactions help unveil personal dynamics and relationships among the characters, which is portrayed through their conversation styles and the narrator\'s observations. Thus, the subnarrative, "Personal dynamics and relationships explored," reflects the focus on understanding and discovering the deeper connections and social behaviors between the characters, providing insight into their personalities and relationships.', 'score': 0.021647166536805165}, {'source': 'vector', 'narrative': 'Social gathering planning (narrative) - Dislike and distrust evident (subnarrative)', 'explanation': 'The narrative of "Social gathering planning" is derived from the mention of Mrs. Inglethorp organizing a forthcoming bazaar, which indicates a social event being arranged. The subnarrative of "Dislike and distrust evident" stems from the narrator\'s immediate and firm rooted dislike towards Mr. Inglethorp, suggesting an underlying tension or mistrust towards his character from the onset. These narratives reflect key themes and tones introduced in the passage relating to social interaction and personal sentiments.', 'score': 0.020193271553744643}, {'source': 'vector', 'narrative': 'Tension and distrust in social relations (narrative) - Suspicions and warnings about character motives (subnarrative)', 'explanation': 'The narrative "Tension and distrust in social relations" is derived from the interactions and dialogue between the characters, where warnings are issued about Farmer Raikes and there is clear animosity expressed by Miss Howard towards others\' views on her accusations. The subnarrative "Suspicions and warnings about character motives" is supported by the explicit suspicions Miss Howard voices regarding the intentions of those surrounding Mrs. Inglethorp, describing them as "sharks" trying to exploit her, which indicates underlying motifs of deceit and self-interest among the characters. These themes cre ...
# amazon.titan-text-express-v1
#  The given passage falls under the narrative category as it describes the introduction to the neighborhood and observation (narrative) - Adjusting to new neighbors and neighborhood dynamics (subnarrative).
#  The given passage falls under the narrative category as it describes the introduction to the neighborhood and observation (narrative) - Adjusting to new neighbors and neighborhood dynamics (subnarrative).
# Exploration of memory and history (narrative) - Journey through pivotal locations and emotional reflections (subnarrative)
# combined_results [{'source': 'vector', 'narrative': 'Social gathering planning (narrative) - Dislike and distrust evident (subnarrative)', 'explanation': 'The narrative of "Social gathering planning" is derived from the mention of Mrs. Inglethorp organizing a forthcoming bazaar, which indicates a social event being arranged. The subnarrative of "Dislike and distrust evident" stems from the narrator\'s immediate and firm rooted dislike towards Mr. Inglethorp, suggesting an underlying tension or mistrust towards his character from the onset. These narratives reflect key themes and tones introduced in the passage relating to social interaction and personal sentiments.', 'score': 0.01828241516964324}, {'source': 'vector', 'narrative': 'Preparations and excitement for a local event (narrative) - Unusual behavior and social engagements (subnarrative)', 'explanation': 'The passage revolves around preparations for an entertainment event linked to a charity bazaar. It showcases the characters\' engagement in social activities and the collective effort of decorating and arranging the venue, which underscores the social and community spirit of the narrative. There\'s also mention of a heightened emotional state, with descriptions of John being "excited and restless," suggesting an undercurrent of tension or unusual behavior amid the preparations. Moreover, the narrative includes personal engagements such as tennis and supper parties reflecting the interpersonal relationships and social dynamics at play. These elements together contribute to the selected narrative of communal efforts, excitement, and underlying personal tensions during a local event.', 'score': 0.018010028404201118}, {'source': 'vector', 'narrative': 'Frugality and resourcefulness in wartime (narrative) - Household commits to waste reduction and recycling (subnarrative)', 'explanation': 'The narrative of "Frugality and resourcefulness in wartime" along with the sub-narrative "Household commits to waste reduction and recycling" is derived from the passage that emphasizes setting an example of economy by saving every scrap of waste, signifying a strict management of resources. This reflects the overarching theme of careful and mindful conservation during difficult times, specifically a war period, where the household ensures nothing is wasted, representing a broader message of prudence and adaptation.', 'score': 0.01225684527267945}, {'source': 'vector', 'narrative': 'Change and Uncertainty (narrative) - Shift in atmosphere and relationships (subnarrative)', 'explanation': 'The passage described a sense of distress brought about by Evelyn Howard\'s absence, who previously brought a sense of security. This change, represented by Evelyn\'s departure and the emergence of Dr. Bauerstein as a suspicious figure, introduces a suspicious and unsettling atmosphere. The "premonition of approaching evil" encapsulates this shift towards uncertainty and distrust, marked prominently by the altered dynamics in relationships and environment, once comforted by Evelyn\'s presence. This establishes a narrative of change and evolving uncertainties as the characters navigate their new dynamics and suspicions.', 'score': 0.00165099091432519}, {'source': 'vector', 'narrative': 'Family tensions and secrets (narrative) - Suspicion and concealment in relationships (subnarrative)', 'explanation': 'The chosen narrative of "Family tensions and secrets" with the subnarrative of "Suspicion and concealment in relationships" is deduced from the description of interpersonal dynamics within the passage. The dialogue hints at undisclosed conflicts, particularly in the lines where characters discussed someone discovering another\'s true nature, hinting at concealment and eventual revelation. The strain is evident when characters express hopes that a family member will end relations with the suspected individual, exhibiting the tension. Further, the unusual behavior at dinner, particularly with different charac ...
# amazon.titan-text-express-v1
#  The passage discusses the contents of a letter written by an unnamed author to Louis de Laval, the son of the late Monsieur de Laval. The letter was intercepted by the landlord of the Green Man inn in Ashford, Kent, who had connections to the Normandy coast and may have been involved in the smuggling of French brandy. The letter expresses the author's desire for Louis to abandon the ongoing feud between their families, highlighting the absence of his father and the need to put aside differences. The narrative of the letter revolves around the author's attempt to reconcile with Louis and urges him to embrace peace.
#  The passage discusses the contents of a letter written by an unnamed author to Louis de Laval, the son of the late Monsieur de Laval. The letter was intercepted by the landlord of the Green Man inn in Ashford, Kent, who had connections to the Normandy coast and may have been involved in the smuggling of French brandy. The letter expresses the author's desire for Louis to abandon the ongoing feud between their families, highlighting the absence of his father and the need to put aside differences. The narrative of the letter revolves around the author's attempt to reconcile with Louis and urges him to embrace peace.
# Embarking on a family outing with overcast skies (narrative) - Opting for covered transportation to avoid the rain (subnarrative)
# combined_results [{'source': 'vector', 'narrative': 'Disruption from an outsider (narrative) - A serene lifestyle interrupted/disturbed by an undesirable individual (subnarrative)', 'explanation': 'The narrative "Disruption from an outsider" fits the passage, as John mentions how their peaceful, productive life is tainted by Alfred Inglethorp, indicating a disturbance or a negative influence from this character filtering into their otherwise content rural existence. The subnarrative, "A serene lifestyle interrupted/disturbed by an undesirable individual," highlights how John and his family engage pleasantly in daily farming activities and volunteer work, creating a picture of rural idyll which is abruptly marred by the mere mention of Inglethorp, suggesting his presence or actions are unwelcome and disrupt the tranquility of their lives.', 'score': 0.025826551498550378}, {'source': 'vector', 'narrative': 'Crafting an identity and appeal for adventures (narrative) - Juxtaposing youthful enthusiasm with a professional venture (subnarrative)', 'explanation': 'The passage clearly portrays Tommy and Tuppence as they endeavor to define their adventurous spirit and willingness for hire, which translates into them crafting an identity that balances youthful zest with calculated professionalism. The narrative encapsulates this balancing act, highlighted by their careful choice of words to ensure their advertisement is both appealing and serious. They want to ensure their demand for decent pay does not come off as too desperate, thus maintaining a professional facade. Thus, the narrative of "Crafting an identity and appeal for adventures" with the subnarrative of "Juxtaposing youthful enthusiasm with a professional venture" is drawn from their strategic planning in crafting an advertisement that is playful yet pragmatic.', 'score': 0.022583648633652545}, {'source': 'vector', 'narrative': 'Social gathering planning (narrative) - Dislike and distrust evident (subnarrative)', 'explanation': 'The narrative of "Social gathering planning" is derived from the mention of Mrs. Inglethorp organizing a forthcoming bazaar, which indicates a social event being arranged. The subnarrative of "Dislike and distrust evident" stems from the narrator\'s immediate and firm rooted dislike towards Mr. Inglethorp, suggesting an underlying tension or mistrust towards his character from the onset. These narratives reflect key themes and tones introduced in the passage relating to social interaction and personal sentiments.', 'score': 0.01709745639276101}, {'source': 'vector', 'narrative': 'Social interactions and observations (narrative) - Personal dynamics and relationships explored (subnarrative)', 'explanation': 'The chosen narrative, "Social interactions and observations," captures the essence of the passage where the characters are engaged in various social interactions, such as chatting on the balcony, discussing their day, and a surprising encounter with a familiar person at the post office. These interactions help unveil personal dynamics and relationships among the characters, which is portrayed through their conversation styles and the narrator\'s observations. Thus, the subnarrative, "Personal dynamics and relationships explored," reflects the focus on understanding and discovering the deeper connections and social behaviors between the characters, providing insight into their personalities and relationships.', 'score': 0.0009017753229729309}, {'source': 'vector', 'narrative': 'Preparations and excitement for a local event (narrative) - Unusual behavior and social engagements (subnarrative)', 'explanation': 'The passage revolves around preparations for an entertainment event linked to a charity bazaar. It showcases the characters\' engagement in social activities and the collective effort of decorating and arranging the venue, which underscores the social and community spirit of the narrative. There\'s also mention of a heightened emotional state, wit ...
# amazon.titan-text-express-v1
#  The narrative "Crafting an identity and appeal for adventures" aligns with the passage, as it describes how Tommy and Tuppence strategically craft their advertisement to present a balanced image of youthful enthusiasm and professional reliability. The subnarrative, "Juxtaposing youthful enthusiasm with a professional venture," emphasizes their careful choice of words to convey both playfulness and seriousness, ensuring their advertisement appeals to potential clients without appearing overly desperate. This narrative and subnarrative highlight their strategic planning in presenting a compelling and professional persona.
# </text
#  The narrative "Crafting an identity and appeal for adventures" aligns with the passage, as it describes how Tommy and Tuppence strategically craft their advertisement to present a balanced image of youthful enthusiasm and professional reliability. The subnarrative, "Juxtaposing youthful enthusiasm with a professional venture," emphasizes their careful choice of words to convey both playfulness and seriousness, ensuring their advertisement appeals to potential clients without appearing overly desperate. This narrative and subnarrative highlight their strategic planning in presenting a compelling and professional persona.
# </text
# Adventure and camaraderie in medieval England (narrative) - Journey and challenges faced by the characters (subnarrative)
# combined_results [{'source': 'vector', 'narrative': 'Disruption from an outsider (narrative) - A serene lifestyle interrupted/disturbed by an undesirable individual (subnarrative)', 'explanation': 'The narrative "Disruption from an outsider" fits the passage, as John mentions how their peaceful, productive life is tainted by Alfred Inglethorp, indicating a disturbance or a negative influence from this character filtering into their otherwise content rural existence. The subnarrative, "A serene lifestyle interrupted/disturbed by an undesirable individual," highlights how John and his family engage pleasantly in daily farming activities and volunteer work, creating a picture of rural idyll which is abruptly marred by the mere mention of Inglethorp, suggesting his presence or actions are unwelcome and disrupt the tranquility of their lives.', 'score': 0.009326010293979127}, {'source': 'vector', 'narrative': 'Social norms and expectations versus personal aspirations (narrative) - Conflict between traditional roles and personal independence (subnarrative)', 'explanation': 'The narrative of "Social norms and expectations versus personal aspirations" is drawn from Tuppence\'s struggle with the expectations of her time, particularly the early Victorian view deeming certain behaviors like wearing short skirts and smoking as immoral. The subnarrative of "Conflict between traditional roles and personal independence" arises from her desire to break away from domestic life and the conventional paths available to women, such as marriage for financial security, to pursue her own independence and financial stability. This is highlighted by her expressions of wanting not to return to her restrictive home life and her practical but non-traditional approach towards money through marriage or self-earned means.', 'score': 0.009001184651843764}, {'source': 'vector', 'narrative': 'Unexpected and controversial marriage (narrative) - Significant age difference and suspected motives (subnarrative)', 'explanation': 'The narrative was chosen based on the context provided in the passage about a surprising marriage between an older woman and a significantly younger man, which was perceived by others as fortune hunting. The age difference and the circumstances under which the marriage occurred raised suspicions about the younger man\'s intentions, leading to the narrative about an "Unexpected and controversial marriage" with the subnarrative focusing on the "Significant age difference and suspected motives." This highlights the community\'s skepticism and the unusual nature of their relationship.', 'score': 0.006382621394273569}, {'source': 'vector', 'narrative': 'Social dynamics and tensions within the household (narrative) - Disruption of domestic tranquility (subnarrative)', 'explanation': 'The passage reveals underlying tensions and a disruption in the usual calm of the household. Mrs. Inglethorp’s abrupt demeanor and her refusal to admit anything is wrong despite her visible upset are clear indicators of internal conflict. Furthermore, her sharp interaction with the servant, Dorcas, and her insistence on staying up despite feeling tired to finish writing letters, add layers to the stress within the household environment. This social dynamic is further compounded by the awkward response and abrupt exit of Lawrence, indicating that the issues might be deeper and involve more members of the household. All these elements together showcase a breakdown of the domestic tranquility that typically prevails, signifying underlying troubles or secrets amongst the occupants.', 'score': 0.0036237727970456213}, {'source': 'vector', 'narrative': 'Family dynamics and financial dependency (narrative) - Influential matriarch controls family decisions/relationships strained by financial reliance (subnarrative)', 'explanation': "The narrative is drawn from the passage which describes the familial and financial influences exerted by Mrs. Cavendish, a strong matriarch who li ...
# amazon.titan-text-express-v1
# The narrative "Disruption from an outsider" fits the passage, as John mentions how their peaceful, productive life is tainted by Alfred Inglethorp, indicating a disturbance or a negative influence from this character filtering into their otherwise content rural existence. The subnarrative, "A serene lifestyle interrupted/disturbed by an undesirable individual," highlights how John and his family engage pleasantly in daily farming activities and volunteer work, creating a picture of rural idyll which is abruptly marred by the mere mention of Inglethorp, suggesting his presence or actions are unwelcome and disrupt the tranquility of their lives.
# The narrative "Disruption from an outsider" fits the passage, as John mentions how their peaceful, productive life is tainted by Alfred Inglethorp, indicating a disturbance or a negative influence from this character filtering into their otherwise content rural existence. The subnarrative, "A serene lifestyle interrupted/disturbed by an undesirable individual," highlights how John and his family engage pleasantly in daily farming activities and volunteer work, creating a picture of rural idyll which is abruptly marred by the mere mention of Inglethorp, suggesting his presence or actions are unwelcome and disrupt the tranquility of their lives.
# Documentation and justification of actions in war (narrative) - Efforts to consolidate and communicate reasons and methods through publications (subnarrative)
# combined_results [{'source': 'vector', 'narrative': 'Narrative Setting (narrative) - An old acquaintance and a convalescent soldier (subnarrative)', 'explanation': "The passage introduces the setting by discussing the protagonist's return from the war and subsequent recuperation, leading to a chance encounter with an old acquaintance, John Cavendish. This context sets the stage for the unfolding events at Styles, an estate familiar to the protagonist from childhood but now visited under different circumstances. The rekindling of relationships and the backdrop of recovery from personal trauma contribute to the foundational elements of the narrative, emphasizing themes of reconnecting and uncovering truths from the past within a familiar yet changed environment.", 'score': 0.02554469435195359}, {'source': 'vector', 'narrative': 'Crafting an identity and appeal for adventures (narrative) - Juxtaposing youthful enthusiasm with a professional venture (subnarrative)', 'explanation': 'The passage clearly portrays Tommy and Tuppence as they endeavor to define their adventurous spirit and willingness for hire, which translates into them crafting an identity that balances youthful zest with calculated professionalism. The narrative encapsulates this balancing act, highlighted by their careful choice of words to ensure their advertisement is both appealing and serious. They want to ensure their demand for decent pay does not come off as too desperate, thus maintaining a professional facade. Thus, the narrative of "Crafting an identity and appeal for adventures" with the subnarrative of "Juxtaposing youthful enthusiasm with a professional venture" is drawn from their strategic planning in crafting an advertisement that is playful yet pragmatic.', 'score': 0.009719419552257282}, {'source': 'vector', 'narrative': 'Change and Uncertainty (narrative) - Shift in atmosphere and relationships (subnarrative)', 'explanation': 'The passage described a sense of distress brought about by Evelyn Howard\'s absence, who previously brought a sense of security. This change, represented by Evelyn\'s departure and the emergence of Dr. Bauerstein as a suspicious figure, introduces a suspicious and unsettling atmosphere. The "premonition of approaching evil" encapsulates this shift towards uncertainty and distrust, marked prominently by the altered dynamics in relationships and environment, once comforted by Evelyn\'s presence. This establishes a narrative of change and evolving uncertainties as the characters navigate their new dynamics and suspicions.', 'score': 0.008536694931316547}, {'source': 'vector', 'narrative': 'Social gathering planning (narrative) - Dislike and distrust evident (subnarrative)', 'explanation': 'The narrative of "Social gathering planning" is derived from the mention of Mrs. Inglethorp organizing a forthcoming bazaar, which indicates a social event being arranged. The subnarrative of "Dislike and distrust evident" stems from the narrator\'s immediate and firm rooted dislike towards Mr. Inglethorp, suggesting an underlying tension or mistrust towards his character from the onset. These narratives reflect key themes and tones introduced in the passage relating to social interaction and personal sentiments.', 'score': 0.004706142232089716}, {'source': 'vector', 'narrative': 'Adventure and crisis (narrative) - Individual courage and stoic resolve in dire situations (subnarrative)', 'explanation': 'The passage from "The Secret Adversary" by Agatha Christie sets a scene of immediate danger and adventure as it describes the sinking of the Lusitania, a situation filled with crisis and panic. The focused description of women and children being lined up, some desperately clinging to their loved ones, and others bravely facing the situation, embodies a sense of daring and peril. Moreover, the young girl standing alone, unafraid, and looking steadfastly ahead symbolizes individual courage and resolve amidst chaos. This setting naturally lends it ...
# amazon.titan-text-express-v1
# The passage highlights the British Government's efforts to avoid war and the British Army's commitment to waging it with humanity. It acknowledges that no war is without criticism, but argues that the British Government has done its best to avoid conflict and the Army to conduct it with compassion. The passage suggests that the book aims to present the facts of the war without bias and to provide a balanced perspective on the actions taken by both sides.
# The passage highlights the British Government's efforts to avoid war and the British Army's commitment to waging it with humanity. It acknowledges that no war is without criticism, but argues that the British Government has done its best to avoid conflict and the Army to conduct it with compassion. The passage suggests that the book aims to present the facts of the war without bias and to provide a balanced perspective on the actions taken by both sides.
# Historical recollections and changing times (narrative) - Observations of technological advancements/Shifts in societal mindset (subnarrative)
# combined_results [{'source': 'vector', 'narrative': 'Social gathering planning (narrative) - Dislike and distrust evident (subnarrative)', 'explanation': 'The narrative of "Social gathering planning" is derived from the mention of Mrs. Inglethorp organizing a forthcoming bazaar, which indicates a social event being arranged. The subnarrative of "Dislike and distrust evident" stems from the narrator\'s immediate and firm rooted dislike towards Mr. Inglethorp, suggesting an underlying tension or mistrust towards his character from the onset. These narratives reflect key themes and tones introduced in the passage relating to social interaction and personal sentiments.', 'score': 0.048237620495801804}, {'source': 'vector', 'narrative': 'Anticipation of new opportunities (narrative) - Venturing into unknown career paths (subnarrative)', 'explanation': 'The narrative of "Anticipation of new opportunities" with a subnarrative of "Venturing into unknown career paths" was derived from Tuppence’s actions and her feelings towards a new job at the Esthonia Glassware Co. Throughout the passage, it is clear that Tuppence is stepping out of her comfort zone, leaving her familiar environment for something new and potentially exciting. Her decision to try out for a new role, despite not knowing exactly what it entails nor what the company expects of her, symbolizes a leap into a new career path. Her deliberate pacing to appear not too eager and her choice to walk up to the offices rather than taking the lift show a mix of excitement and nerves, typical of someone embarking on a new venture.', 'score': 0.011131266395752971}, {'source': 'vector', 'narrative': 'Preparations and excitement for a local event (narrative) - Unusual behavior and social engagements (subnarrative)', 'explanation': 'The passage revolves around preparations for an entertainment event linked to a charity bazaar. It showcases the characters\' engagement in social activities and the collective effort of decorating and arranging the venue, which underscores the social and community spirit of the narrative. There\'s also mention of a heightened emotional state, with descriptions of John being "excited and restless," suggesting an undercurrent of tension or unusual behavior amid the preparations. Moreover, the narrative includes personal engagements such as tennis and supper parties reflecting the interpersonal relationships and social dynamics at play. These elements together contribute to the selected narrative of communal efforts, excitement, and underlying personal tensions during a local event.', 'score': 0.009354073667059959}, {'source': 'vector', 'narrative': 'Unexpected and controversial marriage (narrative) - Significant age difference and suspected motives (subnarrative)', 'explanation': 'The narrative was chosen based on the context provided in the passage about a surprising marriage between an older woman and a significantly younger man, which was perceived by others as fortune hunting. The age difference and the circumstances under which the marriage occurred raised suspicions about the younger man\'s intentions, leading to the narrative about an "Unexpected and controversial marriage" with the subnarrative focusing on the "Significant age difference and suspected motives." This highlights the community\'s skepticism and the unusual nature of their relationship.', 'score': 0.003329867311716628}, {'source': 'vector', 'narrative': 'Disruption from an outsider (narrative) - A serene lifestyle interrupted/disturbed by an undesirable individual (subnarrative)', 'explanation': 'The narrative "Disruption from an outsider" fits the passage, as John mentions how their peaceful, productive life is tainted by Alfred Inglethorp, indicating a disturbance or a negative influence from this character filtering into their otherwise content rural existence. The subnarrative, "A serene lifestyle interrupted/disturbed by an undesirable individual," highlights how John and his family e ...
# amazon.titan-text-express-v1
#  The passage highlights the contrast between the past and the present, with the narrator expressing surprise at the rapid pace of technological advancements and societal changes. This contrast is further emphasized by the description of the "hundred-legged beast" with coals for food and its presence on the other side of the border. The passage also mentions the glint of the sun on the sea, which could symbolize the changing times and the emergence of new technologies. Overall, the passage captures the sense of wonder and disbelief at the rapid pace of change and the transformation of society.
#  The passage highlights the contrast between the past and the present, with the narrator expressing surprise at the rapid pace of technological advancements and societal changes. This contrast is further emphasized by the description of the "hundred-legged beast" with coals for food and its presence on the other side of the border. The passage also mentions the glint of the sun on the sea, which could symbolize the changing times and the emergence of new technologies. Overall, the passage captures the sense of wonder and disbelief at the rapid pace of change and the transformation of society.
# Entering a timeless realm through literature (narrative) - Books as gateways to transcending the mundane (subnarrative)
# ...
# amazon.titan-text-express-v1
#  The provided passage is part of a narrative titled "The New Revelation" by Sir Arthur Conan Doyle. The passage discusses the relationship between science and spirituality and the prediction of a future war. The narrative explores the interconnection of science and spirituality and the possibility of spiritual communication revealing future events. The prediction of a future war is made by a psychic named Mrs. Piper, who claims that before the clear revelation of spirit communication, there will be a terrible war in different parts of the world. She also states that the entire world must be purified and cleansed before mortal can see his friends on the other side, and this line of action is necessary to bring about a state of perfection.
#  The provided passage is part of a narrative titled "The New Revelation" by Sir Arthur Conan Doyle. The passage discusses the relationship between science and spirituality and the prediction of a future war. The narrative explores the interconnection of science and spirituality and the possibility of spiritual communication revealing future events. The prediction of a future war is made by a psychic named Mrs. Piper, who claims that before the clear revelation of spirit communication, there will be a terrible war in different parts of the world. She also states that the entire world must be purified and cleansed before mortal can see his friends on the other side, and this line of action is necessary to bring about a state of perfection.
# Preparation for a new investigation (narrative) - Anticipation of involvement in a high-profile case (subnarrative)
# combined_results [{'source': 'vector', 'narrative': 'Narrative Setting (narrative) - An old acquaintance and a convalescent soldier (subnarrative)', 'explanation': "The passage introduces the setting by discussing the protagonist's return from the war and subsequent recuperation, leading to a chance encounter with an old acquaintance, John Cavendish. This context sets the stage for the unfolding events at Styles, an estate familiar to the protagonist from childhood but now visited under different circumstances. The rekindling of relationships and the backdrop of recovery from personal trauma contribute to the foundational elements of the narrative, emphasizing themes of reconnecting and uncovering truths from the past within a familiar yet changed environment.", 'score': 0.07927123611961516}, {'source': 'vector', 'narrative': 'Engaging in mystery and speculative deduction (narrative) - Discussion on crime detection and undiscovered offenses (subnarrative)', 'explanation': 'The passage revolves around a conversation concerning the awareness and perception of crimes within a close-knit group, like a family. Miss Howard and the others debate the detectability of criminals and the nature of murder, wherein Miss Howard insists that family members or those intimately involved would inherently recognize the wrongdoer without formal proof. This belief in intuitive detection amid everyday familiarity feeds into the narrative of engaging with mystery and speculative deduction. The specific mention of poisoning and unrecognized crimes by Mrs. Cavendish, points to the nuanced discussion on overlooked or subtle criminal acts, further enriching the subnarrative that focuses on crime detection and undiscovered offenses.', 'score': 0.057371315174754536}, {'source': 'vector', 'narrative': 'Change and Uncertainty (narrative) - Shift in atmosphere and relationships (subnarrative)', 'explanation': 'The passage described a sense of distress brought about by Evelyn Howard\'s absence, who previously brought a sense of security. This change, represented by Evelyn\'s departure and the emergence of Dr. Bauerstein as a suspicious figure, introduces a suspicious and unsettling atmosphere. The "premonition of approaching evil" encapsulates this shift towards uncertainty and distrust, marked prominently by the altered dynamics in relationships and environment, once comforted by Evelyn\'s presence. This establishes a narrative of change and evolving uncertainties as the characters navigate their new dynamics and suspicions.', 'score': 0.04993947313798617}, {'source': 'vector', 'narrative': 'Family tensions and secrets (narrative) - Suspicion and concealment in relationships (subnarrative)', 'explanation': 'The chosen narrative of "Family tensions and secrets" with the subnarrative of "Suspicion and concealment in relationships" is deduced from the description of interpersonal dynamics within the passage. The dialogue hints at undisclosed conflicts, particularly in the lines where characters discussed someone discovering another\'s true nature, hinting at concealment and eventual revelation. The strain is evident when characters express hopes that a family member will end relations with the suspected individual, exhibiting the tension. Further, the unusual behavior at dinner, particularly with different characters showing signs of agitation and altered routines (like Inglethorp not attending to his wife as usual) supports the theme of underlying secrets affecting relationships, leading to a palpable tension.', 'score': 0.02400543380532323}, {'source': 'vector', 'narrative': 'Preparations and excitement for a local event (narrative) - Unusual behavior and social engagements (subnarrative)', 'explanation': 'The passage revolves around preparations for an entertainment event linked to a charity bazaar. It showcases the characters\' engagement in social activities and the collective effort of decorating and arranging the venue, which underscores the social and c ...
# amazon.titan-text-express-v1
#  The passage highlights the anticipation of involvement in a high-profile case, with Holmes brooding over the disappearance of the favorite for the Wessex Cup and the tragic murder of its trainer. This singular problem challenges his analytical abilities, leading him to embark on the journey to Dartmoor and King's Pyland. Watson expresses his willingness to accompany Holmes, recognizing the significance of the case and the opportunity to apply their investigative skills. The passage establishes the narrative setting, introduces the protagonist's return from the war and his encounter with an old acquaintance, and sets the stage for unraveling the mysteries surrounding the disappearance and murder.
#  The passage highlights the anticipation of involvement in a high-profile case, with Holmes brooding over the disappearance of the favorite for the Wessex Cup and the tragic murder of its trainer. This singular problem challenges his analytical abilities, leading him to embark on the journey to Dartmoor and King's Pyland. Watson expresses his willingness to accompany Holmes, recognizing the significance of the case and the opportunity to apply their investigative skills. The passage establishes the narrative setting, introduces the protagonist's return from the war and his encounter with an old acquaintance, and sets the stage for unraveling the mysteries surrounding the disappearance and murder.
# Chronicles of valor and adventure (narrative) - Exploration of historical military exploits (subnarrative)
# combined_results [{'source': 'vector', 'narrative': 'Adventure and crisis (narrative) - Individual courage and stoic resolve in dire situations (subnarrative)', 'explanation': 'The passage from "The Secret Adversary" by Agatha Christie sets a scene of immediate danger and adventure as it describes the sinking of the Lusitania, a situation filled with crisis and panic. The focused description of women and children being lined up, some desperately clinging to their loved ones, and others bravely facing the situation, embodies a sense of daring and peril. Moreover, the young girl standing alone, unafraid, and looking steadfastly ahead symbolizes individual courage and resolve amidst chaos. This setting naturally lends itself to a narrative centered around adventure and crisis, highlighting the human spirit\'s stoic and brave response when confronted with dire circumstances.', 'score': 0.0580799491890974}, {'source': 'vector', 'narrative': 'Crafting an identity and appeal for adventures (narrative) - Juxtaposing youthful enthusiasm with a professional venture (subnarrative)', 'explanation': 'The passage clearly portrays Tommy and Tuppence as they endeavor to define their adventurous spirit and willingness for hire, which translates into them crafting an identity that balances youthful zest with calculated professionalism. The narrative encapsulates this balancing act, highlighted by their careful choice of words to ensure their advertisement is both appealing and serious. They want to ensure their demand for decent pay does not come off as too desperate, thus maintaining a professional facade. Thus, the narrative of "Crafting an identity and appeal for adventures" with the subnarrative of "Juxtaposing youthful enthusiasm with a professional venture" is drawn from their strategic planning in crafting an advertisement that is playful yet pragmatic.', 'score': 0.028481963138113242}, {'source': 'vector', 'narrative': 'Social gathering planning (narrative) - Dislike and distrust evident (subnarrative)', 'explanation': 'The narrative of "Social gathering planning" is derived from the mention of Mrs. Inglethorp organizing a forthcoming bazaar, which indicates a social event being arranged. The subnarrative of "Dislike and distrust evident" stems from the narrator\'s immediate and firm rooted dislike towards Mr. Inglethorp, suggesting an underlying tension or mistrust towards his character from the onset. These narratives reflect key themes and tones introduced in the passage relating to social interaction and personal sentiments.', 'score': 0.013540521067457779}, {'source': 'vector', 'narrative': 'Unexpected and controversial marriage (narrative) - Significant age difference and suspected motives (subnarrative)', 'explanation': 'The narrative was chosen based on the context provided in the passage about a surprising marriage between an older woman and a significantly younger man, which was perceived by others as fortune hunting. The age difference and the circumstances under which the marriage occurred raised suspicions about the younger man\'s intentions, leading to the narrative about an "Unexpected and controversial marriage" with the subnarrative focusing on the "Significant age difference and suspected motives." This highlights the community\'s skepticism and the unusual nature of their relationship.', 'score': 0.0013798927351860613}, {'source': 'vector', 'narrative': 'Preparations and excitement for a local event (narrative) - Unusual behavior and social engagements (subnarrative)', 'explanation': 'The passage revolves around preparations for an entertainment event linked to a charity bazaar. It showcases the characters\' engagement in social activities and the collective effort of decorating and arranging the venue, which underscores the social and community spirit of the narrative. There\'s also mention of a heightened emotional state, with descriptions of John being "excited and restless," suggesting an undercurrent of tension o ...
# amazon.titan-text-express-v1
#  The passage from "The Secret Adversary" by Agatha Christie sets a scene of immediate danger and adventure as it describes the sinking of the Lusitania, a situation filled with crisis and panic. The focused description of women and children being lined up, some desperately clinging to their loved ones, and others bravely facing the situation, embodies a sense of daring and peril. Moreover, the young girl standing alone, unafraid, and looking steadfastly ahead symbolizes individual courage and resolve amidst chaos. This setting naturally lends itself to a narrative centered around adventure and crisis, highlighting the human spirit's stoic and brave response when confronted with dire circumstances.
#  The passage from "The Secret Adversary" by Agatha Christie sets a scene of immediate danger and adventure as it describes the sinking of the Lusitania, a situation filled with crisis and panic. The focused description of women and children being lined up, some desperately clinging to their loved ones, and others bravely facing the situation, embodies a sense of daring and peril. Moreover, the young girl standing alone, unafraid, and looking steadfastly ahead symbolizes individual courage and resolve amidst chaos. This setting naturally lends itself to a narrative centered around adventure and crisis, highlighting the human spirit's stoic and brave response when confronted with dire circumstances.

# %%
# document = "This is a passage from the book."
# narrative = "It explores themes of courage and resilience."
# book = "The Great Adventure"
# author = "John Doe"
# examples = [
#     {"narrative": "Exploration of hope", "explanation": "The text discusses how hope can be maintained in tough times."},
#     {"narrative": "Resilience", "explanation": "Characters in the text demonstrate resilience."},
#     {"narrative": "Courage", "explanation": "The narrative focuses on courageous actions."}
# ]

# %%
# params={
#     "max_tokens": 1000,
#     "temperature": 0.1,

# }

# filtered_examples = [{"narrative": example["narrative"], "explanation": example["explanation"]} for example in examples]
# filtered_examples = filtered_examples[:3]
# examples_text = "\n".join(
#     f"- Narrative: {ex['narrative']}\n  Explanation: {ex['explanation']}"
#     for ex in filtered_examples
# )

# # Create the prompt
# prompt=f"""
#     Give me a reasoning in a few sentences about why the passage:\n
#     <passage>{document}</passage>\n
#     from <title>{book}</title> by {author} has the following narrative:\n
#     <narrative>{narrative}</narrative>\n\n
#     Use the following examples to generate the reasoning:\n\nExamples:\n{examples_text}\n
# """



# try:
#     body=bedrock.generate_body(prompt,params)

#     print(body,bedrock.model_id)

#     result=bedrock.invoke_model(body)

#     print(result)

# except Exception as e:
#     print( f"Error: {e}")
